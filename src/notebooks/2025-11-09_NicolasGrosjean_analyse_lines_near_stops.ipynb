# %% [markdown]
# 🚌 Projet MDM - Mobilité Durable en Montagne ⛰️
#
# *Author : Nicolas Grosjean*
#
# *Date : 09/11/2025*
#
# **Description :**
#
# Analyses bus data with C2C activity points :
# - Compute distance between them
# - Identify C2C activity points not deserved
# - Make pretty visualisations to share

# %%
# WORKING DIR NEED TO BE SET BEFORE IMPORTING SETTINGS
import os

os.chdir("../..")
print("Working directory set to the root of the project")
# Out:
# Working directory set to the root of the project

# %%
import folium
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point, box

from src.settings import DATA_FOLDER, EPSG_WEB_MERCATOR, EPSG_WGS84

# %%
department_code = "74"
neighbour_department_codes = {
    "38": ["1", "5", "8", "26", "42", "69", "73"],
    "73": ["1", "5", "38", "74"],
    "74": ["1", "73"],
}

# %% [markdown]
# ## Read data

# %%
from src.processors.osm import AURAOSMBusLinesProcessor, AURAOSMBusStopsProcessor

# %%
osm_stops_gdf = AURAOSMBusStopsProcessor.fetch(reload_pipeline=False)
osm_stops_gdf.loc[:, "source"] = "OSM"
osm_stops_gdf.head()
# Out:
#   gtfs_id navitia_id  osm_id                    name  \
# 0     NaN       None  135296  Université - IUT-STAPS
# 1     NaN       None  135930   Hôpital Couple Enfant
# 2     NaN       None  136570              Cap des H'
# 3     NaN       None  136597  Place de la Libération
# 4     NaN       None  137073             Centr'Alp 2
#
#                             description line_gtfs_ids  \
# 0                                   NaN            []
# 1                                   NaN            []
# 2  Arrêt de régulation, non commercial.            []
# 3                                   NaN            []
# 4                                   NaN            []
#
#                                         line_osm_ids network network_gtfs_id  \
# 0                                          [3922428]  M réso            None
# 1                                 [3333927, 3922430]  M réso            None
# 2                                                 []  M réso            None
# 3  [3031947, 3031948, 3044780, 3044781, 3923550, ...  M réso            None
# 4                        [3090127, 8671286, 8671287]  M réso            None
#
#                    geometry  \
# 0  POINT (5.77622 45.19738)
# 1  POINT (5.74231 45.20065)
# 2  POINT (5.68159 45.21695)
# 3  POINT (5.66272 45.20707)
# 4    POINT (5.6043 45.3198)
#
#                                                other source
# 0  {'access': None, 'addr:city': None, 'addr:hous...    OSM
# 1  {'access': None, 'addr:city': None, 'addr:hous...    OSM
# 2  {'access': None, 'addr:city': None, 'addr:hous...    OSM
# 3  {'access': None, 'addr:city': None, 'addr:hous...    OSM
# 4  {'access': None, 'addr:city': None, 'addr:hous...    OSM

# %%
osm_lines_gdf = AURAOSMBusLinesProcessor.fetch(reload_pipeline=False)
osm_lines_gdf.head()
# Out:
#   gtfs_id  osm_id                                               name  \
# 0     NaN  197669                          40 : Bellecour ⇒ Neuville
# 1     NaN  207979  C7 : Gare Part-Dieu - Vivier Merle ⇒ Hôpital L...
# 2     NaN  225734               Bus 80 : Bel-Air → Saint-Julien SNCF
# 3     NaN  225735               Bus 80 : Saint-Julien SNCF → Bel-Air
# 4     NaN  310305     17 : Gare d'Oullins ⇒ Vourles Z.A. Les Plattes
#
#                    from_location                        to  network  \
# 0                      Bellecour                  Neuville      TCL
# 1  Gare Part-Dieu - Vivier Merle          Hôpital Lyon Sud      TCL
# 2                        Bel-Air         Saint-Julien SNCF  Unireso
# 3              Saint-Julien SNCF                   Bel-Air  Unireso
# 4                 Gare d'Oullins  Vourles Z.A. Les Plattes      TCL
#
#   network_gtfs_id network_wikidata      operator   colour text_colour  \
# 0            None            Q8700   Keolis Lyon  #965340         NaN
# 1            None            Q8700   Keolis Lyon      NaN         NaN
# 2            None         Q1312883  TPG: GEM Bus  #f5b5d2         NaN
# 3            None         Q1312883  TPG: GEM Bus  #f5b5d2         NaN
# 4            None            Q8700   Keolis Lyon  #F7941D         NaN
#
#   stop_gtfs_ids                                      stops_osm_ids  school  \
# 0            []  [4619742845, 2321205056, 2321205046, 210715756...   False
# 1            []  [7376670890, 11596032483, 4576330319, 65875533...   False
# 2            []  [8253534546, 8253534547, 6053855877, 654431699...   False
# 3            []  [10085904782, 7872312632, 1033278418, 45944552...   False
# 4            []  [7495230391, 4645286989, 4645287006, 325711244...   False
#
#   geometry                                              other
# 0     None  {'bicycle': None, 'boundary': None, 'by_night'...
# 1     None  {'bicycle': None, 'boundary': None, 'by_night'...
# 2     None  {'bicycle': None, 'boundary': None, 'by_night'...
# 3     None  {'bicycle': None, 'boundary': None, 'by_night'...
# 4     None  {'bicycle': None, 'boundary': None, 'by_night'...

# %%
# activity_gdf = gpd.read_parquet("src/data/C2C/depart_topos_stops_isere.parquet")
# print(f"{len(activity_gdf)} activity points")
# activity_gdf.rename(
#     columns={"navitia_id": "Id wp", "name": "Name wp", "nombre_de_depart_de_topo": "nbr_topo"},
#     inplace=True,
# )
# activity_gdf = activity_gdf[["Id wp", "Name wp", "geometry", "nbr_topo"]]
# activity_gdf.head()
access_point_df = pd.read_csv(
    DATA_FOLDER / "C2C/c2corg-anonymized.2025-12-10.access_points.csv"
)
print(f"{len(access_point_df)} access points")
activity_gdf = gpd.GeoDataFrame(
    access_point_df,
    geometry=[
        Point(xy) for xy in zip(access_point_df["lon"], access_point_df["lat"], strict=True)
    ],
    crs=EPSG_WGS84,
)
activity_gdf = activity_gdf.rename(
    columns={
        "document_id": "Id wp",
        "title": "Name wp",
    }
)
activity_gdf["nbr_topo"] = "?"
activity_gdf.head()
# Out:
# 8157 access points
#      Id wp         lon        lat                   Name wp  \
# 0  1147027   55.364058 -21.021794  Parking des Cryptomérias
# 1  1186548   -0.358590  42.779283        Formigal - Village
# 2  1587979  170.816308 -43.858069        Fox Peak ski field
# 3   952546   14.510288  46.057894                 Ljubljana
# 4    44261    7.149976  44.202556        Col de la Lombarde
#
#                                          description  \
# 0  Accès depuis Saint-Paul en 45min, route en exc...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4     [img=439892 right]col de la Lombarde[/img]\r\n
#
#                                              summary  \
# 0  Parking de départ pour plusieurs circuits à pi...
# 1  Se garer à proximité de l'hôtel HG Alto Aragon...
# 2                                                NaN
# 3  Ljubljana est la capitale de la Slovénie. Nomb...
# 4                                                NaN
#
#                       geometry nbr_topo
# 0   POINT (55.36406 -21.02179)        ?
# 1    POINT (-0.35859 42.77928)        ?
# 2  POINT (170.81631 -43.85807)        ?
# 3    POINT (14.51029 46.05789)        ?
# 4     POINT (7.14998 44.20256)        ?

# %%
area_gdf = gpd.read_file(DATA_FOLDER / "transportdatagouv/contour-des-departements.geojson")
area_gdf = area_gdf.set_crs(EPSG_WGS84, allow_override=True)
area_gdf.head()
# Out:
#   code                      nom  \
# 0   01                      Ain
# 1   02                    Aisne
# 2   03                   Allier
# 3   04  Alpes-de-Haute-Provence
# 4   05             Hautes-Alpes
#
#                                             geometry
# 0  POLYGON ((4.78021 46.17668, 4.78024 46.18905, ...
# 1  POLYGON ((3.17296 50.01131, 3.17382 50.01186, ...
# 2  POLYGON ((3.03207 46.79491, 3.03424 46.7908, 3...
# 3  POLYGON ((5.67604 44.19143, 5.67817 44.19051, ...
# 4  POLYGON ((6.26057 45.12685, 6.26417 45.12641, ...

# %%
department_activity_df = (
    gpd.sjoin(
        activity_gdf.to_crs(EPSG_WGS84),
        area_gdf[area_gdf["code"] == department_code],
    )
    .loc[:, ["Id wp"]]
    .drop_duplicates()
    .merge(activity_gdf, on="Id wp", how="inner")
)
department_activity_gdf = gpd.GeoDataFrame(department_activity_df, geometry="geometry").set_crs(
    EPSG_WGS84
)
print(
    f"Filter on department {department_code}: keep {len(department_activity_gdf)} on {len(activity_gdf)} activity points"
)
# Out:
# Filter on department 74: keep 531 on 8157 activity points

# %%
tdg_stop_list = []
for area_code in [department_code] + neighbour_department_codes[department_code]:
    tdg_file = DATA_FOLDER / f"transportdatagouv/stops_{area_code}.parquet"
    if not tdg_file.exists():
        err_msg = f"No TransportDataGouv bus stops found for area code {area_code}, please process it first."
        print(err_msg)
    else:
        tdg_stop_list.append(gpd.read_parquet(tdg_file))
tdg_stops_gdf = pd.concat(tdg_stop_list, ignore_index=True)
tdg_stops_gdf.columns = [
    "network_gtfs_id",
    "network",
    "gtfs_id",
    "name",
    "stop_code",
    "description",
    "line_gtfs_ids",
    "geometry",
]
tdg_stops_gdf.loc[:, "source"] = "TDG"
tdg_stops_gdf.head()
# Out:
# No TransportDataGouv bus stops found for area code 1, please process it first.
#   network_gtfs_id        network   gtfs_id                     name stop_code  \
# 0               1  Réseau STAR'T  AL_BOUG1  Allinges Bougeries haut      <NA>
# 1               1  Réseau STAR'T  AL_BOUG2  Allinges Bougeries haut      <NA>
# 2               1  Réseau STAR'T  AL_CENT1               Centenaire      <NA>
# 3               1  Réseau STAR'T  AL_CENT2               Centenaire      <NA>
# 4               1  Réseau STAR'T  AL_CHVI2             Châteauvieux      <NA>
#
#   description                       line_gtfs_ids  \
# 0              {'line_id': 'N', 'line_name': 'N'}
# 1              {'line_id': 'N', 'line_name': 'N'}
# 2              {'line_id': 'N', 'line_name': 'N'}
# 3              {'line_id': 'N', 'line_name': 'N'}
# 4              {'line_id': 'N', 'line_name': 'N'}
#
#                          geometry source
# 0  POINT (721701.703 5836692.071)    TDG
# 1  POINT (721686.151 5836788.756)    TDG
# 2  POINT (721763.463 5835401.431)    TDG
# 3  POINT (721735.688 5835376.292)    TDG
# 4  POINT (720216.634 5833207.795)    TDG

# %%
from src.processors.c2c import C2CBusStopsProcessor

# %%
c2c_stops_gdf = C2CBusStopsProcessor.fetch(reload_pipeline=False).to_crs(EPSG_WGS84)
c2c_stops_gdf.loc[:, "source"] = "C2C"
c2c_stops_gdf.head()
# Out:
#   gtfs_id              navitia_id osm_id  \
# 0    None  stop_area:OVO:S1000374   None
# 1    None   stop_area:O38:4038505   None
# 2    None  stop_area:OVO:S1002339   None
# 3    None  stop_area:OVO:S1001416   None
# 4    None   stop_area:O38:3279412   None
#
#                                                 name description  \
# 0  La Sure en Chartreuse - RD520 Village (La Sure...        None
# 1     RD520 Pommiers Village (La Sure en Chartreuse)        None
# 2  La Sure en Chartreuse - Pommiers Village (La S...        None
# 3  La Sure en Chartreuse - les Barniers (La Sure ...        None
# 4               Les Barniers (La Sure en Chartreuse)        None
#
#   line_gtfs_ids line_osm_ids                   network network_gtfs_id  \
# 0            []           []  M Réso - Pays Voironnais            None
# 1            []           []        Isère - Transisère            None
# 2            []           []  M Réso - Pays Voironnais            None
# 3            []           []  M Réso - Pays Voironnais            None
# 4            []           []        Isère - Transisère            None
#
#                    geometry  \
# 0  POINT (5.65312 45.31916)
# 1  POINT (5.65302 45.31893)
# 2  POINT (5.65543 45.31862)
# 3   POINT (5.65098 45.3155)
# 4  POINT (5.65103 45.31545)
#
#                                                other source
# 0  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C
# 1  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C
# 2  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C
# 3  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C
# 4  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C

# %%
# old_bus_stop_nb = len(c2c_stops_gdf)
# valid_navitia_ids = gpd.sjoin(c2c_stops_gdf, area_gdf[area_gdf["code"] == isere_code])[
#     "navitia_id"
# ].drop_duplicates()
# c2c_stops_gdf = c2c_stops_gdf[c2c_stops_gdf["navitia_id"].isin(valid_navitia_ids)]
# print(f"Filter on Isère: keep {len(c2c_stops_gdf)} on {old_bus_stop_nb} C2C bus stops")

# %%
all_stops_gdf = pd.concat(
    (osm_stops_gdf, tdg_stops_gdf.to_crs(EPSG_WGS84), c2c_stops_gdf.to_crs(EPSG_WGS84))
)
all_stops_gdf.tail()
# Out:
#      gtfs_id                                         navitia_id osm_id  \
# 1259    None                stop_area:ZOS:Navitia:10407-0500300   None
# 1260    None                stop_area:ZOS:Navitia:11868-0500300   None
# 1261    None                             stop_area:O66:66S03936   None
# 1262    None                             stop_area:O66:66S03937   None
# 1263    None  stop_area:R74:Navitia:FR:74134:ZE:58693:HAUTEx...   None
#
#                                                    name description  \
# 1259                       LHôpital Parking (Aiguilles)        None
# 1260                      École Félix Tonda (Aiguilles)        None
# 1261  Arles-sur-Tech - Chbre des Métiers (Arles-sur-...        None
# 1262    Arles-sur-Tech - Gare Routière (Arles-sur-Tech)        None
# 1263                                Les Clos (Les Gets)        None
#
#      line_gtfs_ids line_osm_ids                               network  \
# 1259            []           []                        ZOU ! Scolaire
# 1260            []           []                        ZOU ! Scolaire
# 1261            []           []   Pyrénées-Orientales - liO Occitanie
# 1262            []           []   Pyrénées-Orientales - liO Occitanie
# 1263            []           []  Haute-Savoie - Réseau interurbain 74
#
#      network_gtfs_id                  geometry  \
# 1259            None  POINT (6.86861 44.78044)
# 1260            None  POINT (6.86689 44.78005)
# 1261            None  POINT (2.63124 42.45584)
# 1262            None   POINT (2.63619 42.4584)
# 1263            None  POINT (6.66143 46.15386)
#
#                                                   other source stop_code
# 1259  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C       NaN
# 1260  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C       NaN
# 1261  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C       NaN
# 1262  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C       NaN
# 1263  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C       NaN

# %%
from src.processors.distances import DistancesProcessor

# %%
distance_threshold_km = 5

# %%
distances_df = DistancesProcessor.fetch(reload_pipeline=False)
distances_df.loc[distances_df["distance_m"] > distance_threshold_km * 1000, "distance_m"] = None
nb_lines_before_drop = len(distances_df)
distances_df = distances_df[~pd.isnull(distances_df["distance_m"])]
distances_df = distances_df[
    distances_df["Id wp"].isin(department_activity_df["Id wp"].unique())
]
print(f"{len(distances_df)} distances kept on {nb_lines_before_drop}")
distances_df.head()
# Out:
# 50217 distances kept on 79237337
#            osm_id gtfs_id navitia_id    Id wp  distance_m  computed
# 7021   13798988.0     NaN        NaN   978831      2598.9      True
# 7028   13798988.0     NaN        NaN  1203699      3433.3      True
# 7041   13798988.0     NaN        NaN  1205899      4282.3      True
# 12040  23719915.0     NaN        NaN   337068      4346.6      True
# 12081  23719915.0     NaN        NaN  1204814      3926.5      True

# %% [markdown]
# ## Analyse data

# %%
activity_gdf["Category"] = "Unreachable"
activity_gdf.loc[~activity_gdf["Id wp"].isin(department_activity_df["Id wp"]), "Category"] = (
    "Outside departement"
)
activity_gdf.loc[activity_gdf["Id wp"].isin(distances_df["Id wp"].unique()), "Category"] = (
    "Reachable"
)
activity_gdf.groupby("Category").count()["Id wp"]
# Out:
# Category
# Outside departement    7626
# Reachable               500
# Unreachable              31
# Name: Id wp, dtype: int64

# %% [markdown]
# ### C2C

# %%
near_c2c_stops_gdf = c2c_stops_gdf[
    c2c_stops_gdf["navitia_id"].isin(distances_df["navitia_id"].unique())
]
print(
    f"{len(near_c2c_stops_gdf)} C2C bus stops are near activity points (on {len(c2c_stops_gdf)} bus stops)"
)
# Out:
# 222 C2C bus stops are near activity points (on 1264 bus stops)

# %%
department_navitia_ids = gpd.sjoin(
    c2c_stops_gdf, area_gdf[area_gdf["code"] == department_code]
)["navitia_id"].drop_duplicates()
print(f"{len(department_navitia_ids)} bus stops in the department")
# Out:
# 219 bus stops in the department

# %%
c2c_interesting_columns = ["navitia_id", "name", "network", "geometry", "source", "lines"]
expanded = c2c_stops_gdf["other"].apply(pd.Series)
expanded_c2c_stops_gdf = pd.concat([c2c_stops_gdf.drop(columns=["other"]), expanded], axis=1)
expanded_c2c_stops_gdf["lines"] = expanded_c2c_stops_gdf["stoparea_id_and_line"].apply(
    lambda l: [e["line"] for e in l]
)
expanded_c2c_stops_gdf[c2c_interesting_columns].head()
# Out:
#                navitia_id                                               name  \
# 0  stop_area:OVO:S1000374  La Sure en Chartreuse - RD520 Village (La Sure...
# 1   stop_area:O38:4038505     RD520 Pommiers Village (La Sure en Chartreuse)
# 2  stop_area:OVO:S1002339  La Sure en Chartreuse - Pommiers Village (La S...
# 3  stop_area:OVO:S1001416  La Sure en Chartreuse - les Barniers (La Sure ...
# 4   stop_area:O38:3279412               Les Barniers (La Sure en Chartreuse)
#
#                     network                  geometry source  \
# 0  M Réso - Pays Voironnais  POINT (5.65312 45.31916)    C2C
# 1        Isère - Transisère  POINT (5.65302 45.31893)    C2C
# 2  M Réso - Pays Voironnais  POINT (5.65543 45.31862)    C2C
# 3  M Réso - Pays Voironnais   POINT (5.65098 45.3155)    C2C
# 4        Isère - Transisère  POINT (5.65103 45.31545)    C2C
#
#                                                lines
# 0  [Bus 503 - POMMIER PALLACHERE - VOREPPE GARE S...
# 1  [Bus T40 - ST PIERRE DE CHARTREUSE-GRENOBLE, B...
# 2  [Bus 503 - POMMIER PALLACHERE - VOREPPE GARE S...
# 3  [Bus 503 - POMMIER PALLACHERE - VOREPPE GARE S...
# 4  [Bus T40 - ST PIERRE DE CHARTREUSE-GRENOBLE, B...

# %%
c2c_distances = distances_df.merge(
    expanded_c2c_stops_gdf[c2c_interesting_columns].explode("lines"),
    on="navitia_id",
    how="inner",
)
c2c_distances.head()
# Out:
#    osm_id gtfs_id                                         navitia_id   Id wp  \
# 0     NaN     NaN  stop_area:R74:Navitia:FR:74083:ZE:58837:HAUTEx...  170094
# 1     NaN     NaN  stop_area:R74:Navitia:FR:74083:ZE:58837:HAUTEx...  170094
# 2     NaN     NaN  stop_area:R74:Navitia:FR:74083:ZE:58837:HAUTEx...  170094
# 3     NaN     NaN  stop_area:R74:Navitia:FR:74083:ZE:58837:HAUTEx...  170094
# 4     NaN     NaN  stop_area:R74:Navitia:FR:74083:ZE:58837:HAUTEx...  465228
#
#    distance_m  computed                               name  \
# 0      2385.8      True  Lycée H.B. de Saussure (Combloux)
# 1      2385.8      True  Lycée H.B. de Saussure (Combloux)
# 2      2385.8      True  Lycée H.B. de Saussure (Combloux)
# 3      2385.8      True  Lycée H.B. de Saussure (Combloux)
# 4      4551.3      True  Lycée H.B. de Saussure (Combloux)
#
#                                 network                  geometry source  \
# 0  Haute-Savoie - Réseau interurbain 74  POINT (6.64006 45.89711)    C2C
# 1  Haute-Savoie - Réseau interurbain 74  POINT (6.64006 45.89711)    C2C
# 2  Haute-Savoie - Réseau interurbain 74  POINT (6.64006 45.89711)    C2C
# 3  Haute-Savoie - Réseau interurbain 74  POINT (6.64006 45.89711)    C2C
# 4  Haute-Savoie - Réseau interurbain 74  POINT (6.64006 45.89711)    C2C
#
#                                   lines
# 0           Bus Y81 - CHAMONIX > CLUSES
# 1  Bus Y83 - SALLANCHES > PRAZ > FLUMET
# 2           Bus Y81 - CHAMONIX > CLUSES
# 3  Bus Y83 - SALLANCHES > PRAZ > FLUMET
# 4           Bus Y81 - CHAMONIX > CLUSES

# %%
reachable_c2c_nb = len(c2c_distances[~pd.isnull(c2c_distances["navitia_id"])]["Id wp"].unique())
print(f"{reachable_c2c_nb} activity point access are reachable with C2C data")
# Out:
# 254 activity point access are reachable with C2C data

# %%
c2c_mask = c2c_distances["distance_m"] == c2c_distances.groupby(["Id wp", "lines"])[
    "distance_m"
].transform("min")
c2c_neareast_stops_by_line_gdf = expanded_c2c_stops_gdf[
    expanded_c2c_stops_gdf["navitia_id"].isin(c2c_distances[c2c_mask]["navitia_id"].unique())
]
print(
    f"{len(c2c_neareast_stops_by_line_gdf)} C2C bus stops are the nearest activity points for their bus line (on {len(c2c_stops_gdf)} bus stops)"
)
# Out:
# 162 C2C bus stops are the nearest activity points for their bus line (on 1264 bus stops)

# %%
assert (
    reachable_c2c_nb
    == c2c_distances[
        c2c_distances["navitia_id"].isin(c2c_neareast_stops_by_line_gdf["navitia_id"])
    ]["Id wp"].nunique()
), "Some activity points are no more reachable with only c2c_neareast_stops_by_line_gdf"

# %% [markdown]
# ### OSM

# %%
osm_interesting_columns = [
    "osm_id",
    "name",
    "description",
    "line_osm_ids",
    "network",
    "geometry",
    "source",
]
osm_distances = distances_df.merge(
    osm_stops_gdf[osm_interesting_columns].explode("line_osm_ids"), on="osm_id", how="inner"
)
osm_distances.head()
# Out:
#        osm_id gtfs_id navitia_id    Id wp  distance_m  computed         name  \
# 0  13798988.0     NaN        NaN   978831      2598.9      True  La Comtesse
# 1  13798988.0     NaN        NaN   978831      2598.9      True  La Comtesse
# 2  13798988.0     NaN        NaN   978831      2598.9      True  La Comtesse
# 3  13798988.0     NaN        NaN  1203699      3433.3      True  La Comtesse
# 4  13798988.0     NaN        NaN  1203699      3433.3      True  La Comtesse
#
#   description line_osm_ids network                 geometry source
# 0         NaN      3620143     NaN  POINT (6.71308 45.8911)    OSM
# 1         NaN      3620146     NaN  POINT (6.71308 45.8911)    OSM
# 2         NaN      3620147     NaN  POINT (6.71308 45.8911)    OSM
# 3         NaN      3620143     NaN  POINT (6.71308 45.8911)    OSM
# 4         NaN      3620146     NaN  POINT (6.71308 45.8911)    OSM

# %%
# Keep one bus stop by line and activity
osm_mask = osm_distances["distance_m"] == osm_distances.groupby(["Id wp", "line_osm_ids"])[
    "distance_m"
].transform("min")
osm_neareast_stops_by_line_gdf = osm_stops_gdf[
    osm_stops_gdf["osm_id"].isin(osm_distances[osm_mask]["osm_id"].unique())
]

# For each activity keep also one bus stop with no line data
osm_stops_ids_without_lines = osm_stops_gdf[
    osm_stops_gdf["line_osm_ids"].apply(lambda l: len(l) == 0)
]["osm_id"].unique()
osm_distances_without_lines = osm_distances[
    osm_distances["osm_id"].isin(osm_stops_ids_without_lines)
]
osm_without_lines_mask = osm_distances_without_lines[
    "distance_m"
] == osm_distances_without_lines.groupby(["Id wp"])["distance_m"].transform("min")
osm_neareast_stops_without_line_gdf = osm_stops_gdf[
    osm_stops_gdf["osm_id"].isin(
        osm_distances_without_lines[osm_without_lines_mask]["osm_id"].unique()
    )
]

# Concat them
osm_neareast_stops_by_line_gdf = pd.concat(
    (osm_neareast_stops_by_line_gdf, osm_neareast_stops_without_line_gdf)
)
print(
    f"{len(osm_neareast_stops_by_line_gdf)} OSM bus stops are the nearest activity points for their bus line (on {len(osm_stops_gdf)} bus stops)"
)
# Out:
# 695 OSM bus stops are the nearest activity points for their bus line (on 35498 bus stops)

# %%
line_osm_id_to_name = osm_lines_gdf.set_index("osm_id")["name"].to_dict()
osm_neareast_stops_by_line_gdf.loc[:, "lines"] = osm_neareast_stops_by_line_gdf.loc[
    :, "line_osm_ids"
].apply(lambda l: [line_osm_id_to_name[e] for e in l])

# %%
reachable_osm_nb = len(osm_distances[~pd.isnull(osm_distances["osm_id"])]["Id wp"].unique())
print(f"{reachable_osm_nb} activity point access are reachable with OSM data")
# Out:
# 488 activity point access are reachable with OSM data

# %%
assert (
    reachable_osm_nb
    == osm_distances[osm_distances["osm_id"].isin(osm_neareast_stops_by_line_gdf["osm_id"])][
        "Id wp"
    ].nunique()
), "Some activity points are no more reachable with only osm_neareast_stops_by_line_gdf"

# %% [markdown]
# ### TDG

# %%
tdg_interesting_columns = ["gtfs_id", "name", "line_gtfs_ids", "network", "geometry", "source"]
tdg_distances = distances_df.merge(
    tdg_stops_gdf[tdg_interesting_columns], on="gtfs_id", how="inner"
)
tdg_distances.head()
# Out:
#    osm_id   gtfs_id navitia_id   Id wp  distance_m  computed  \
# 0     NaN  motchat1        NaN  131619      3585.0      True
# 1     NaN  motchat2        NaN  131619      3585.0      True
# 2     NaN  motchef1        NaN  131619      4978.2      True
# 3     NaN  motchef2        NaN  131619      4981.9      True
# 4     NaN    ptreg3        NaN  131619      4978.2      True
#
#                     name                                      line_gtfs_ids  \
# 0       Motz Chateaufort  {'line_id': '501', 'line_name': '501'},{'line_...
# 1       Motz Chateaufort  {'line_id': '505', 'line_name': '505'},{'line_...
# 2  Motz Chef-lieu Mairie  {'line_id': '502', 'line_name': '502'},{'line_...
# 3  Motz Chef-lieu Mairie             {'line_id': '502', 'line_name': '502'}
# 4  Motz Chef-lieu Mairie             {'line_id': '506', 'line_name': '506'}
#
#            network                        geometry source
# 0  Ondéa Grand Lac  POINT (649271.375 5768778.337)    TDG
# 1  Ondéa Grand Lac  POINT (649271.375 5768778.337)    TDG
# 2  Ondéa Grand Lac  POINT (650930.258 5767470.891)    TDG
# 3  Ondéa Grand Lac  POINT (650942.949 5767477.932)    TDG
# 4  Ondéa Grand Lac  POINT (650930.258 5767470.891)    TDG

# %%
tdg_mask = tdg_distances["distance_m"] == tdg_distances.groupby(["Id wp", "line_gtfs_ids"])[
    "distance_m"
].transform("min")
tdg_neareast_stops_by_line_gdf = tdg_stops_gdf[
    tdg_stops_gdf["gtfs_id"].isin(tdg_distances[tdg_mask]["gtfs_id"].unique())
]
print(
    f"{len(tdg_neareast_stops_by_line_gdf)} tdg bus stops are the nearest activity points for their bus line (on {len(tdg_stops_gdf)} bus stops)"
)
# Out:
# 2262 tdg bus stops are the nearest activity points for their bus line (on 14350 bus stops)

# %%
reachable_tdg_nb = len(tdg_distances[~pd.isnull(tdg_distances["gtfs_id"])]["Id wp"].unique())
print(f"{reachable_tdg_nb} activity point access are reachable with TDG data")
# Out:
# 466 activity point access are reachable with TDG data

# %%
assert (
    reachable_tdg_nb
    == tdg_distances[tdg_distances["gtfs_id"].isin(tdg_neareast_stops_by_line_gdf["gtfs_id"])][
        "Id wp"
    ].nunique()
), "Some activity points are no more reachable with tdg_neareast_stops_by_line_gdf"

# %% [markdown]
# # Visualize

# %% [markdown]
# ## All activity points

# %%
color_mapping = {"Outside departement": "gray", "Reachable": "green", "Unreachable": "purple"}
activity_gdf["color"] = activity_gdf["Category"].apply(lambda c: color_mapping[c])

# %%
reachable_nb = sum(activity_gdf["Category"] == "Reachable")
unreachable_nb = sum(activity_gdf["Category"] == "Unreachable")
outside_nb = sum(activity_gdf["Category"] == "Outside departement")
title_html = f"""
    <h4 style="position: fixed; top: 10px; left: 50px; z-index: 9999; background: rgba(255,255,255,0.8); padding: 6px 10px; margin: 0;">
    Points d'accès d'activité CampToCamp.<br>
    - {reachable_nb} points à moins de {distance_threshold_km}km d'un arrêt de bus (<span style=\"color: green\">vert</span>)<br>
    - {unreachable_nb} points à plus de {distance_threshold_km}km d'un arrêt de bus (<span style=\"color: purple\">violet</span>)<br>
    - {outside_nb} points en dehors du département (<span style=\"color: gray\">gris</span>)
    </h4>
"""

# %%
# Plot points with bus data far from distance_threshold m

# Add a base OSM map centered on Grenoble
m = folium.Map(
    location=[45.1885, 5.7245], zoom_start=9, tiles="OpenStreetMap", control_scale=True
)

# Add Waymarked Trails hiking layers
folium.TileLayer(tiles="WaymarkedTrails.hiking").add_to(m)

# Add Isère polygon
isere_latlon_coords = [
    (lat, lon)
    for lon, lat in area_gdf[area_gdf["code"] == department_code]["geometry"]
    .values[0]
    .exterior.coords
]
folium.Polygon(
    locations=isere_latlon_coords,
    color="black",
    weight=3,
    fill_color="black",
    fill_opacity=0.25,
    fill=True,
).add_to(m)

# Add activity markers
columns_to_display = ["Id wp", "Name wp", "nbr_topo"]
folium.GeoJson(
    activity_gdf[columns_to_display + ["color", "geometry"]],
    zoom_on_click=True,
    marker=folium.Marker(icon=folium.Icon(icon="star")),
    tooltip=folium.GeoJsonTooltip(fields=columns_to_display),
    popup=folium.GeoJsonPopup(fields=columns_to_display),
    style_function=lambda x: {
        "markerColor": x["properties"]["color"],
    },
).add_to(m)

# Add title
m.get_root().html.add_child(folium.Element(title_html))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a6d99185ce8a90a6af33efee83f618d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h4 style=&quot;position: fixed; top: 10px; left: 50px; z-index: 9999; background: rgba(255,255,255,0.8); padding: 6px 10px; margin: 0;&quot;&gt;
#     Points d&#x27;accès d&#x27;activité CampToCamp.&lt;br&gt;
#     - 362 points à moins de 5km d&#x27;un arrêt de bus (&lt;span style=&quot;color: green&quot;&gt;vert&lt;/span&gt;)&lt;br&gt;
#     - 87 points à plus de 5km d&#x27;un arrêt de bus (&lt;span style=&quot;color: purple&quot;&gt;violet&lt;/span&gt;)&lt;br&gt;
#     - 7708 points en dehors du département (&lt;span style=&quot;color: gray&quot;&gt;gris&lt;/span&gt;)
#     &lt;/h4&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a6d99185ce8a90a6af33efee83f618d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a6d99185ce8a90a6af33efee83f618d = L.map(
#                 &quot;map_5a6d99185ce8a90a6af33efee83f618d&quot;,
#                 {
#                     center: [45.1885, 5.7245],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_5a6d99185ce8a90a6af33efee83f618d);
#
#
#
#
#
#             var tile_layer_074ec791750896306237fcb566deae6e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_074ec791750896306237fcb566deae6e.addTo(map_5a6d99185ce8a90a6af33efee83f618d);
#
#
#             var tile_layer_fcec4439f0f212f01ce36ae9159861dd = L.tileLayer(
#                 &quot;https://tile.waymarkedtrails.org/hiking/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map data: \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors | Map style: \u0026copy; \u003ca href=\&quot;https://waymarkedtrails.org\&quot;\u003ewaymarkedtrails.org\u003c/a\u003e (\u003ca href=\&quot;https://creativecommons.org/licenses/by-sa/3.0/\&quot;\u003eCC-BY-SA\u003c/a\u003e)&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fcec4439f0f212f01ce36ae9159861dd.addTo(map_5a6d99185ce8a90a6af33efee83f618d);
#
#
#             var polygon_cd509e940ca21ac448550ed240d58f81 = L.polygon(
#                 [[45.77837, 6.80252], [45.77525, 6.80181], [45.77132, 6.80426], [45.76979, 6.80638], [45.76859, 6.805], [45.76489, 6.80503], [45.76395, 6.80598], [45.76229, 6.8059], [45.75994, 6.80488], [45.7564, 6.80537], [45.75515, 6.805], [45.75183, 6.80594], [45.75046, 6.80719], [45.74846, 6.80562], [45.74503, 6.80812], [45.74362, 6.81076], [45.74332, 6.81267], [45.74168, 6.81427], [45.7403, 6.81725], [45.73909, 6.81605], [45.73604, 6.81543], [45.73332, 6.81385], [45.73142, 6.8115], [45.73013, 6.81127], [45.72908, 6.80926], [45.72728, 6.80814], [45.72515, 6.80842], [45.72425, 6.81053], [45.72113, 6.81427], [45.71938, 6.81863], [45.71868, 6.81935], [45.71524, 6.8197], [45.71131, 6.82221], [45.7095, 6.82471], [45.70762, 6.82642], [45.70435, 6.82719], [45.70283, 6.82911], [45.70201, 6.83149], [45.70237, 6.83602], [45.7004, 6.84139], [45.69904, 6.84167], [45.69702, 6.84349], [45.69189, 6.84687], [45.6902, 6.84634], [45.68767, 6.8532], [45.68551, 6.8563], [45.68469, 6.86022], [45.68461, 6.86542], [45.68396, 6.86697], [45.68096, 6.86859], [45.6801, 6.87117], [45.67865,

# %%
m.save("all_activity_points.html")

# %% [markdown]
# ## Filtered bus data with activities

# %%
import json

# %%
def list_to_str_with_br(l: list[str], line_number_limit: int = 10) -> str:
    list_to_process = l[:line_number_limit]
    if len(l) > line_number_limit:
        list_to_process += ["..."]
    return "<br>".join(list_to_process)

# %%
def get_tdg_line_names(lines: str) -> str:
    lines_json = "[" + lines.replace("'", '"') + "]"
    # TODO Remove this bugfix
    lines_json = lines_json.replace('Mobi"Aix', "Mobi'Aix")
    data = json.loads(lines_json)
    return list_to_str_with_br([d["line_name"] for d in data])

# %%
bus_stop_nb = {
    "TDG": len(tdg_neareast_stops_by_line_gdf),
    "OSM": len(osm_neareast_stops_by_line_gdf),
    "C2C": len(c2c_neareast_stops_by_line_gdf),
}
fields_by_source = {
    "TDG": ["gtfs_id", "name", "network", "line_gtfs_ids"],
    "OSM": ["osm_id", "name", "network", "lines"],
    "C2C": ["navitia_id", "name", "network", "lines"],
}
aliases_by_source = {
    "TDG": [f"<b>Arrêt de bus TDG</b><br>ID :", "Nom :", "Réseau :", "Lignes :"],
    "OSM": [f"<b>Arrêt de bus OSM</b><br>ID :", "Nom :", "Réseau :", "Lignes :"],
    "C2C": [f"<b>Arrêt de bus C2C</b><br>ID :", "Nom :", "Réseau :", "Lignes :"],
}
tdg_stops_to_plot = tdg_neareast_stops_by_line_gdf[
    fields_by_source["TDG"] + ["geometry"]
].copy()
tdg_stops_to_plot["line_gtfs_ids"] = tdg_neareast_stops_by_line_gdf["line_gtfs_ids"].apply(
    get_tdg_line_names
)
osm_stops_to_plot = osm_neareast_stops_by_line_gdf[
    fields_by_source["OSM"] + ["geometry"]
].copy()
osm_stops_to_plot["lines"] = osm_stops_to_plot["lines"].apply(list_to_str_with_br)
c2c_stops_to_plot = c2c_neareast_stops_by_line_gdf[
    fields_by_source["C2C"] + ["geometry"]
].copy()
c2c_stops_to_plot["lines"] = c2c_stops_to_plot["lines"].apply(list_to_str_with_br)
gdf_by_source = {"TDG": tdg_stops_to_plot, "OSM": osm_stops_to_plot, "C2C": c2c_stops_to_plot}

# %%
title_html = f"""
    <div style="position: fixed; top: 10px; left: 50px; z-index: 9999; background: rgba(255,255,255,0.8); padding: 6px 10px; margin: 0;">
        <h2>Couverture des points d'accès CampToCamp<br>desservis ou non par arrêts de bus<br>(selon sources associés : TDG, OSM, C2C)</h2>
        <h4>
            - {reachable_nb} points à moins de {distance_threshold_km}km d'un arrêt de bus (<span style=\"color: green\">vert</span>)<br>
            - {unreachable_nb} points à plus de {distance_threshold_km}km d'un arrêt de bus (<span style=\"color: purple\">violet</span>)<br>
            <br>
            - {reachable_tdg_nb} points accessibles avec les données TDG<br>
            - {reachable_osm_nb} points accessibles avec les données OSM<br>
            - {reachable_c2c_nb} points accessibles avec les données C2C<br>
        </h4>
    </div>
"""

# %%
# Add a base OSM map centered on Grenoble
m = folium.Map(
    location=[45.1885, 5.7245], zoom_start=9, tiles="OpenStreetMap", control_scale=True
)

# Add Waymarked Trails hiking layers
folium.TileLayer(tiles="WaymarkedTrails.hiking", control=False).add_to(m)

# Add Isère polygon
isere_latlon_coords = [
    (lat, lon)
    for lon, lat in area_gdf[area_gdf["code"] == department_code]["geometry"]
    .values[0]
    .exterior.coords
]
folium.Polygon(
    locations=isere_latlon_coords,
    color="black",
    weight=3,
    fill_color="black",
    fill_opacity=0.25,
    fill=True,
).add_to(m)

# Add bus markers
source_to_id = {"TDG": "gtfs_id", "OSM": "osm_id", "C2C": "navitia_id"}
for source in ["TDG", "OSM", "C2C"]:
    fg = folium.FeatureGroup(name=f"Bus stops from {source} ({bus_stop_nb[source]})", show=True)
    fields = fields_by_source[source]
    aliases = aliases_by_source[source]
    folium.GeoJson(
        gdf_by_source[source][fields + ["geometry"]],
        zoom_on_click=True,
        marker=folium.Marker(icon=folium.Icon(icon="bus", prefix="fa", color="blue")),
        tooltip=folium.GeoJsonTooltip(fields=fields, aliases=aliases),
        popup=folium.GeoJsonPopup(fields=fields, aliases=aliases),
    ).add_to(fg)
    fg.add_to(m)


# Add activity markers
fg = folium.FeatureGroup(name="C2C activity access point", show=True)
aliases = [f"<b>Point d'accès d'activité</b><br>ID :", "Nom :", "Nombre de topos :"]
folium.GeoJson(
    activity_gdf[activity_gdf["Category"] != "Outside departement"][
        columns_to_display + ["color", "geometry"]
    ],
    zoom_on_click=True,
    marker=folium.Marker(icon=folium.Icon(icon="star")),
    tooltip=folium.GeoJsonTooltip(fields=columns_to_display, aliases=aliases),
    popup=folium.GeoJsonPopup(fields=columns_to_display, aliases=aliases),
    style_function=lambda x: {
        "markerColor": x["properties"]["color"],
    },
).add_to(fg)
fg.add_to(m)

# Add layer control to filter layers
folium.LayerControl(collapsed=False).add_to(m)

# Add title
m.get_root().html.add_child(folium.Element(title_html))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78bc230457ab9278cc44c00c61e3db97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed; top: 10px; left: 50px; z-index: 9999; background: rgba(255,255,255,0.8); padding: 6px 10px; margin: 0;&quot;&gt;
#         &lt;h2&gt;Couverture des points d&#x27;accès CampToCamp&lt;br&gt;desservis ou non par arrêts de bus&lt;br&gt;(selon sources associés : TDG, OSM, C2C)&lt;/h2&gt;
#         &lt;h4&gt;
#             - 362 points à moins de 5km d&#x27;un arrêt de bus (&lt;span style=&quot;color: green&quot;&gt;vert&lt;/span&gt;)&lt;br&gt;
#             - 87 points à plus de 5km d&#x27;un arrêt de bus (&lt;span style=&quot;color: purple&quot;&gt;violet&lt;/span&gt;)&lt;br&gt;
#             &lt;br&gt;
#             - 292 points accessibles avec les données TDG&lt;br&gt;
#             - 361 points accessibles avec les données OSM&lt;br&gt;
#             - 139 points accessibles avec les données C2C&lt;

# %%
m.save(
    f"one_bus_by_line_and_source_at_distance_{distance_threshold_km}_km_department_{department_code}.html"
)
