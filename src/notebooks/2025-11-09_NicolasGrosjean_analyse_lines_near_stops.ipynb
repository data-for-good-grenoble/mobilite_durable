# %% [markdown]
# 🚌 Projet MDM - Mobilité Durable en Montagne ⛰️
#
# *Author : Nicolas Grosjean*
#
# *Date : 09/11/2025*
#
# **Description :**
#
# Analyses bus data with C2C activity points :
# - Compute distance between them
# - Identify C2C activity points not deserved
# - Make pretty visualisations to share

# %%
# WORKING DIR NEED TO BE SET BEFORE IMPORTING SETTINGS
import os

os.chdir("../..")
print("Working directory set to the root of the project")
# Out:
# Working directory set to the root of the project

# %%
import folium
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point, box

from src.settings import EPSG_WEB_MERCATOR, EPSG_WGS84

# %%
isere_code = "38"

# %% [markdown]
# ## Read data

# %%
from src.processors.osm import OSMBusLinesProcessor, OSMBusStopsProcessor

# %%
osm_stops_gdf = OSMBusStopsProcessor.fetch(reload_pipeline=False).set_crs(
    EPSG_WGS84
)  # TODO Remove CRS
osm_stops_gdf.loc[:, "source"] = "OSM"
osm_stops_gdf.head()
# Out:
#   gtfs_id navitia_id  osm_id                    name  \
# 0    None       None  135296  Université - IUT-STAPS
# 1    None       None  135930   Hôpital Couple Enfant
# 2    None       None  136570              Cap des H'
# 3    None       None  136597  Place de la Libération
# 4    None       None  137073             Centr'Alp 2
#
#                             description line_gtfs_ids  \
# 0                                  None            []
# 1                                  None            []
# 2  Arrêt de régulation, non commercial.            []
# 3                                  None            []
# 4                                  None            []
#
#                                         line_osm_ids network network_gtfs_id  \
# 0                                          [3922428]  M réso            None
# 1                                 [3333927, 3922430]  M réso            None
# 2                                                 []  M réso            None
# 3  [3031947, 3031948, 3044780, 3044781, 3923550, ...  M réso            None
# 4                                 [8671286, 8671287]  M réso            None
#
#                    geometry  \
# 0  POINT (5.77622 45.19738)
# 1  POINT (5.74231 45.20065)
# 2  POINT (5.68159 45.21695)
# 3  POINT (5.66272 45.20707)
# 4    POINT (5.6043 45.3198)
#
#                                                other source
# 0  {'alt_name': None, 'amenity': None, 'bench': N...    OSM
# 1  {'alt_name': None, 'amenity': None, 'bench': N...    OSM
# 2  {'alt_name': None, 'amenity': None, 'bench': N...    OSM
# 3  {'alt_name': None, 'amenity': None, 'bench': N...    OSM
# 4  {'alt_name': None, 'amenity': None, 'bench': N...    OSM

# %%
osm_lines_gdf = OSMBusLinesProcessor.fetch(reload_pipeline=False)
osm_lines_gdf.head()
# Out:
#   gtfs_id   osm_id                                               name  \
# 0    None  2067887  Ligne A : Gare de Saint-Clair-Les-Roches ⇒ Ron...
# 1    None  2569190  Ouibus 70 : Grenoble Gare Routière -> Aéroport...
# 2    None  2569239  Ouibus 70 : Aéroport Lyon Saint-Exupéry -> Pla...
# 3    None  2920548   15 : Bois Français => Grenoble (via Chenevières)
# 4    None  2920549   15 : Grenoble => Bois Français (via Chenevières)
#
#                               from_location  \
# 0            Gare de Saint-Clair-Les-Roches
# 1                  Grenoble - Gare Routière
# 2  Aéroport Lyon Saint-Exupéry - Terminal 1
# 3              Saint Ismier - Bois Français
# 4              Grenoble - Verdun-Préfecture
#
#                                          to    network network_gtfs_id  \
# 0                         Rond-point Chanas        TPR            None
# 1  Aéroport Lyon Saint-Exupéry - Terminal 1  BlaBlaBus            None
# 2                  Grenoble - Gare routière  BlaBlaBus            None
# 3              Grenoble - Verdun-Préfecture     M réso            None
# 4              Saint Ismier - Bois Français     M réso            None
#
#   network_wikidata                       operator   colour text_colour  \
# 0             None  Courriers Rhodaniens / Fayard   e53b1a        None
# 1         Q1653380                  Faure Vercors  #ee0064        None
# 2         Q1653380                  Faure Vercors  #ee0064        None
# 3       Q131689044                            VFD  #1f72b9        None
# 4       Q131689044                            VFD  #1f72b9        None
#
#   stop_gtfs_ids                                      stops_osm_ids  school  \
# 0            []  [1659415935, 8874916309, 11146173165, 11146173...   False
# 1            []                [2617010911, 474827289, 6074566590]   False
# 2            []                [6074566590, 457759141, 2617010911]   False
# 3            []  [2299463674, 513946287, 513946283, 513946279, ...   False
# 4            []  [372746162, 451116247, 1829688368, 1829874475,...   False
#
#   geometry                                              other
# 0     None  {'charge': None, 'check_date': None, 'comment'...
# 1     None  {'charge': None, 'check_date': None, 'comment'...
# 2     None  {'charge': None, 'check_date': None, 'comment'...
# 3     None  {'charge': None, 'check_date': None, 'comment'...
# 4     None  {'charge': None, 'check_date': None, 'comment'...

# %%
activity_gdf = gpd.read_parquet("src/data_2/C2C/depart_topos_stops_isere.parquet")
print(f"{len(activity_gdf)} activity points")
activity_gdf.rename(
    columns={"navitia_id": "Id wp", "name": "Name wp", "nombre_de_depart_de_topo": "nbr_topo"},
    inplace=True,
)
activity_gdf = activity_gdf[["Id wp", "Name wp", "geometry", "nbr_topo"]]
activity_gdf.head()
# Out:
# 577 activity points
#    Id wp                               Name wp                  geometry  \
# 0  38440                        Pierre Blanche  POINT (5.52399 44.88944)
# 1  39041  Alpe d'Huez - Falaises du lac Besson  POINT (6.09444 45.11727)
# 2  39108         Les Arias d'en bas (Mariande)  POINT (6.17616 44.91703)
# 3  39178            Cirque inférieur du Boulon  POINT (5.96136 45.19128)
# 4  39195          Le Bourg-d'Oisans - Commères   POINT (6.08117 45.0272)
#
#    nbr_topo
# 0         3
# 1         5
# 2         1
# 3         1
# 4        11

# %%
area_gdf = gpd.read_file("src/data/transportdatagouv/contour-des-departements.geojson")
area_gdf = area_gdf.set_crs(EPSG_WGS84, allow_override=True)
area_gdf.head()
# Out:
#   code                      nom  \
# 0   01                      Ain
# 1   02                    Aisne
# 2   03                   Allier
# 3   04  Alpes-de-Haute-Provence
# 4   05             Hautes-Alpes
#
#                                             geometry
# 0  POLYGON ((4.78021 46.17668, 4.78024 46.18905, ...
# 1  POLYGON ((3.17296 50.01131, 3.17382 50.01186, ...
# 2  POLYGON ((3.03207 46.79491, 3.03424 46.7908, 3...
# 3  POLYGON ((5.67604 44.19143, 5.67817 44.19051, ...
# 4  POLYGON ((6.26057 45.12685, 6.26417 45.12641, ...

# %%
isere_activity_df = (
    gpd.sjoin(
        activity_gdf.to_crs(EPSG_WGS84),
        area_gdf[area_gdf["code"] == isere_code].to_crs(EPSG_WGS84),
    )
    .loc[:, ["Id wp"]]
    .drop_duplicates()
    .merge(activity_gdf, on="Id wp", how="inner")
)
isere_activity_gdf = gpd.GeoDataFrame(isere_activity_df, geometry="geometry").set_crs(
    EPSG_WGS84
)
print(f"Filter on Isère: keep {len(isere_activity_gdf)} on {len(activity_gdf)}")
# Out:
# Filter on Isère: keep 514 on 577

# %%
tdg_stops_gdf = gpd.read_parquet(
    os.path.join(os.getcwd(), f"src/data/transportdatagouv/stops_{isere_code}.parquet")
)
tdg_stops_gdf.columns = [
    "network_gtfs_id",
    "network",
    "gtfs_id",
    "name",
    "stop_code",
    "description",
    "line_gtfs_ids",
    "geometry",
]
tdg_stops_gdf.loc[:, "source"] = "TDG"
tdg_stops_gdf.head()
# Out:
#                  network_gtfs_id                       network  \
# 0  CARSxREGIONxAIN:Network:1:LOC      REGION - cars Région Ain
# 1  CARSxREGIONxAIN:Network:1:LOC      REGION - cars Région Ain
# 2  CARSxREGIONxAIN:Network:1:LOC      REGION - cars Région Ain
# 3          ARDECHE:Network:1:LOC  REGION - cars Région Ardèche
# 4          ARDECHE:Network:1:LOC  REGION - cars Région Ardèche
#
#                              gtfs_id       name stop_code description  \
# 0  FR:38261:ZE:38367:CARSxREGIONxAIN    La gare   1136154        <NA>
# 1  FR:38055:ZE:38540:CARSxREGIONxAIN     Mairie   1137588        <NA>
# 2  FR:38465:ZE:38541:CARSxREGIONxAIN      Place   1137590        <NA>
# 3          FR:38298:ZE:40822:ARDECHE  Gare SNCF   1023073        <NA>
# 4          FR:38349:ZE:41169:ARDECHE     Mairie   1027195        <NA>
#
#                                        line_gtfs_ids  \
# 0  {'line_id': 'CARSxREGIONxAIN:FlexibleLine:1005...
# 1  {'line_id': 'CARSxREGIONxAIN:FlexibleLine:1005...
# 2  {'line_id': 'CARSxREGIONxAIN:FlexibleLine:1005...
# 3  {'line_id': 'ARDECHE:Line:1000601:LOC', 'line_...
# 4  {'line_id': 'ARDECHE:Line:1000601:LOC', 'line_...
#
#                          geometry source
# 0    POINT (608999.29 5727934.37)    TDG
# 1  POINT (615432.365 5731543.476)    TDG
# 2  POINT (612596.334 5731950.939)    TDG
# 3  POINT (533823.813 5680267.662)    TDG
# 4  POINT (531434.796 5671771.274)    TDG

# %%
from src.processors.c2c import C2CBusStopsProcessor

# %%
c2c_stops_gdf = C2CBusStopsProcessor.fetch(reload_pipeline=False)
c2c_stops_gdf.loc[:, "source"] = "C2C"
c2c_stops_gdf.head()
# Out:
#   gtfs_id              navitia_id osm_id  \
# 0    None  stop_area:OGE:GEN15846   None
# 1    None  stop_area:OGE:GEN15852   None
# 2    None  stop_area:OGE:GEN15850   None
# 3    None  stop_area:OGE:GEN15080   None
# 4    None  stop_area:OGE:GEN13054   None
#
#                                                 name description  \
# 0   Le Haut-Bréda, Pinsot le Village (Le Haut-Bréda)        None
# 1  Le Haut-Bréda, Hot Pic Belle Etoile (Le Haut-B...        None
# 2            Le Haut-Bréda, Chinfert (Le Haut-Bréda)        None
# 3             Le Haut-Bréda, la Piat (Le Haut-Bréda)        None
# 4                     Domène, Domène Mairie (Domène)        None
#
#   line_gtfs_ids line_osm_ids              network network_gtfs_id  \
# 0            []           []  Mobilités M - TouGo            None
# 1            []           []  Mobilités M - TouGo            None
# 2            []           []  Mobilités M - TouGo            None
# 3            []           []  Mobilités M - TouGo            None
# 4            []           []    Mobilités M - Tag            None
#
#                          geometry  \
# 0  POINT (679047.781 5677868.337)
# 1  POINT (678910.858 5678497.283)
# 2  POINT (678788.406 5679655.482)
# 3  POINT (678378.751 5675153.444)
# 4  POINT (649900.998 5653440.123)
#
#                                                other source
# 0  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C
# 1  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C
# 2  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C
# 3  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C
# 4  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C

# %%
all_stops_gdf = pd.concat(
    (osm_stops_gdf, tdg_stops_gdf.to_crs(EPSG_WGS84), c2c_stops_gdf.to_crs(EPSG_WGS84))
)
all_stops_gdf.tail()
# Out:
# /tmp/ipykernel_6910/3211379376.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_stops_gdf = pd.concat(
#     gtfs_id             navitia_id  osm_id  \
# 645    None  stop_area:O38:3226468     NaN
# 646    None  stop_area:O38:3224622     NaN
# 647    None  stop_area:O38:3224623     NaN
# 648    None  stop_area:O38:3224627     NaN
# 649    None  stop_area:O38:3224625     NaN
#
#                                                   name description  \
# 645                                      École (Auris)        None
# 646             Les Égaux (Saint-Pierre-de-Chartreuse)        None
# 647            Gérentière (Saint-Pierre-de-Chartreuse)        None
# 648  École de Saint-Hugues (Saint-Pierre-de-Chartre...        None
# 649          Saint-Hugues (Saint-Pierre-de-Chartreuse)        None
#
#     line_gtfs_ids line_osm_ids             network network_gtfs_id  \
# 645            []           []  Isère - Transisère            None
# 646            []           []  Isère - Transisère            None
# 647            []           []  Isère - Transisère            None
# 648            []           []  Isère - Transisère            None
# 649            []           []  Isère - Transisère            None
#
#                      geometry  \
# 645    POINT (6.0865 45.0459)
# 646  POINT (5.80145 45.31654)
# 647  POINT (5.80912 45.31962)
# 648  POINT (5.80637 45.32302)
# 649  POINT (5.80648 45.32368)
#
#                                                  other source stop_code
# 645  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C      <NA>
# 646  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C      <NA>
# 647  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C      <NA>
# 648  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C      <NA>
# 649  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C      <NA>

# %%
from src.processors.distances import DistancesProcessor

# %%
distance_threshold_km = 5

# %%
distances_df = DistancesProcessor.fetch(reload_pipeline=False)
distances_df[distances_df["distance_m"] > distance_threshold_km * 1000] = None
nb_lines_before_drop = len(distances_df)
distances_df = distances_df[~pd.isnull(distances_df["distance_m"])]
print(f"{len(distances_df)} distances kept on {nb_lines_before_drop}")
distances_df.head()
# Out:
# 50427 distances kept on 11555748
#        osm_id gtfs_id navitia_id      Id wp  distance_m
# 451  135296.0    None       None  1198615.0      3832.8
# 548  135930.0    None       None   102210.0      2548.2
# 599  135930.0    None       None   104323.0      2765.7
# 633  135930.0    None       None   104564.0      4859.1
# 817  135930.0    None       None   224381.0      3877.0

# %% [markdown]
# ## Analyse data

# %%
activity_gdf["Category"] = "Unreachable"
activity_gdf.loc[~activity_gdf["Id wp"].isin(isere_activity_df["Id wp"]), "Category"] = (
    "Outside departement"
)
activity_gdf.loc[activity_gdf["Id wp"].isin(distances_df["Id wp"].unique()), "Category"] = (
    "Reachable"
)
activity_gdf.groupby("Category").count()["Id wp"]
# Out:
# Category
# Outside departement     63
# Reachable              479
# Unreachable             35
# Name: Id wp, dtype: int64

# %% [markdown]
# ### C2C

# %%
near_c2c_stops_gdf = c2c_stops_gdf[
    c2c_stops_gdf["navitia_id"].isin(distances_df["navitia_id"].unique())
]
print(
    f"{len(near_c2c_stops_gdf)} C2C bus stops are near activity points (on {len(c2c_stops_gdf)} bus stops)"
)
# Out:
# 642 C2C bus stops are near activity points (on 650 bus stops)

# %%
c2c_interesting_columns = ["navitia_id", "name", "network", "geometry", "source", "lines"]
expanded = c2c_stops_gdf["other"].apply(pd.Series)
expanded_c2c_stops_gdf = pd.concat([c2c_stops_gdf.drop(columns=["other"]), expanded], axis=1)
expanded_c2c_stops_gdf["lines"] = expanded_c2c_stops_gdf["stoparea_id_and_line"].apply(
    lambda l: [e["line"] for e in l]
)
expanded_c2c_stops_gdf[c2c_interesting_columns].head()
# Out:
#                navitia_id                                               name  \
# 0  stop_area:OGE:GEN15846   Le Haut-Bréda, Pinsot le Village (Le Haut-Bréda)
# 1  stop_area:OGE:GEN15852  Le Haut-Bréda, Hot Pic Belle Etoile (Le Haut-B...
# 2  stop_area:OGE:GEN15850            Le Haut-Bréda, Chinfert (Le Haut-Bréda)
# 3  stop_area:OGE:GEN15080             Le Haut-Bréda, la Piat (Le Haut-Bréda)
# 4  stop_area:OGE:GEN13054                     Domène, Domène Mairie (Domène)
#
#                network                        geometry source  \
# 0  Mobilités M - TouGo  POINT (679047.781 5677868.337)    C2C
# 1  Mobilités M - TouGo  POINT (678910.858 5678497.283)    C2C
# 2  Mobilités M - TouGo  POINT (678788.406 5679655.482)    C2C
# 3  Mobilités M - TouGo  POINT (678378.751 5675153.444)    C2C
# 4    Mobilités M - Tag  POINT (649900.998 5653440.123)    C2C
#
#                                                lines
# 0                  [Bus 79 - ALLEVARD ECOLE PLEIADE]
# 1                  [Bus 79 - ALLEVARD ECOLE PLEIADE]
# 2  [Bus 79 - ALLEVARD ECOLE PLEIADE, Bus 79 - ALL...
# 3  [Bus 79 - ALLEVARD ECOLE PLEIADE, Bus 79 - ALL...
# 4  [Bus 15 - GRENOBLE Verdun - Préfecture / DOMÈN...

# %%
c2c_distances = distances_df.merge(
    expanded_c2c_stops_gdf[c2c_interesting_columns].explode("lines"),
    on="navitia_id",
    how="inner",
)
c2c_distances.head()
# Out:
#    osm_id gtfs_id              navitia_id     Id wp  distance_m  \
# 0     NaN    None  stop_area:OGE:GEN15846  104317.0      3372.3
# 1     NaN    None  stop_area:OGE:GEN15846  104456.0      3452.4
# 2     NaN    None  stop_area:OGE:GEN15852  104317.0      3855.7
# 3     NaN    None  stop_area:OGE:GEN15852  104456.0      2986.9
# 4     NaN    None  stop_area:OGE:GEN15850  104456.0      3093.8
#
#                                                 name              network  \
# 0   Le Haut-Bréda, Pinsot le Village (Le Haut-Bréda)  Mobilités M - TouGo
# 1   Le Haut-Bréda, Pinsot le Village (Le Haut-Bréda)  Mobilités M - TouGo
# 2  Le Haut-Bréda, Hot Pic Belle Etoile (Le Haut-B...  Mobilités M - TouGo
# 3  Le Haut-Bréda, Hot Pic Belle Etoile (Le Haut-B...  Mobilités M - TouGo
# 4            Le Haut-Bréda, Chinfert (Le Haut-Bréda)  Mobilités M - TouGo
#
#                          geometry source                            lines
# 0  POINT (679047.781 5677868.337)    C2C  Bus 79 - ALLEVARD ECOLE PLEIADE
# 1  POINT (679047.781 5677868.337)    C2C  Bus 79 - ALLEVARD ECOLE PLEIADE
# 2  POINT (678910.858 5678497.283)    C2C  Bus 79 - ALLEVARD ECOLE PLEIADE
# 3  POINT (678910.858 5678497.283)    C2C  Bus 79 - ALLEVARD ECOLE PLEIADE
# 4  POINT (678788.406 5679655.482)    C2C  Bus 79 - ALLEVARD ECOLE PLEIADE

# %%
reachable_c2c_nb = len(c2c_distances[~pd.isnull(c2c_distances["navitia_id"])]["Id wp"].unique())
print(f"{reachable_c2c_nb} activity point access are reachable with C2C data")
# Out:
# 411 activity point access are reachable with C2C data

# %%
c2c_mask = c2c_distances["distance_m"] == c2c_distances.groupby(["Id wp", "lines"])[
    "distance_m"
].transform("min")
c2c_neareast_stops_by_line_gdf = expanded_c2c_stops_gdf[
    expanded_c2c_stops_gdf["navitia_id"].isin(c2c_distances[c2c_mask]["navitia_id"].unique())
]
print(
    f"{len(c2c_neareast_stops_by_line_gdf)} C2C bus stops are the nearest activity points for their bus line (on {len(c2c_stops_gdf)} bus stops)"
)
# Out:
# 423 C2C bus stops are the nearest activity points for their bus line (on 650 bus stops)

# %% [markdown]
# ### OSM

# %%
osm_interesting_columns = [
    "osm_id",
    "name",
    "description",
    "line_osm_ids",
    "network",
    "geometry",
    "source",
]
osm_distances = distances_df.merge(
    osm_stops_gdf[osm_interesting_columns].explode("line_osm_ids"), on="osm_id", how="inner"
)
osm_distances.head()
# Out:
#      osm_id gtfs_id navitia_id      Id wp  distance_m                    name  \
# 0  135296.0    None       None  1198615.0      3832.8  Université - IUT-STAPS
# 1  135930.0    None       None   102210.0      2548.2   Hôpital Couple Enfant
# 2  135930.0    None       None   102210.0      2548.2   Hôpital Couple Enfant
# 3  135930.0    None       None   104323.0      2765.7   Hôpital Couple Enfant
# 4  135930.0    None       None   104323.0      2765.7   Hôpital Couple Enfant
#
#   description line_osm_ids network                  geometry source
# 0        None      3922428  M réso  POINT (5.77622 45.19738)    OSM
# 1        None      3333927  M réso  POINT (5.74231 45.20065)    OSM
# 2        None      3922430  M réso  POINT (5.74231 45.20065)    OSM
# 3        None      3333927  M réso  POINT (5.74231 45.20065)    OSM
# 4        None      3922430  M réso  POINT (5.74231 45.20065)    OSM

# %%
osm_mask = osm_distances["distance_m"] == osm_distances.groupby(["Id wp", "line_osm_ids"])[
    "distance_m"
].transform("min")
osm_neareast_stops_by_line_gdf = osm_stops_gdf[
    osm_stops_gdf["osm_id"].isin(osm_distances[osm_mask]["osm_id"].unique())
]
print(
    f"{len(osm_neareast_stops_by_line_gdf)} OSM bus stops are the nearest activity points for their bus line (on {len(osm_stops_gdf)} bus stops)"
)
# Out:
# 1309 OSM bus stops are the nearest activity points for their bus line (on 6806 bus stops)

# %%
line_osm_id_to_name = osm_lines_gdf.set_index("osm_id")["name"].to_dict()
osm_neareast_stops_by_line_gdf.loc[:, "lines"] = osm_neareast_stops_by_line_gdf.loc[
    :, "line_osm_ids"
].apply(lambda l: [line_osm_id_to_name[e] for e in l])
# Out:
# /data/hdd/Documents/GitHub/mobilite_durable/.venv/lib/python3.13/site-packages/geopandas/geodataframe.py:1981: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
reachable_osm_nb = len(osm_distances[~pd.isnull(osm_distances["osm_id"])]["Id wp"].unique())
print(f"{reachable_osm_nb} activity point access are reachable with OSM data")
# Out:
# 435 activity point access are reachable with OSM data

# %% [markdown]
# ### TDG

# %%
tdg_interesting_columns = ["gtfs_id", "name", "line_gtfs_ids", "network", "geometry", "source"]
tdg_distances = distances_df.merge(
    tdg_stops_gdf[tdg_interesting_columns], on="gtfs_id", how="inner"
)
tdg_distances.head()
# Out:
#    osm_id gtfs_id navitia_id     Id wp  distance_m                    name  \
# 0     NaN     XGE       None   43666.0      3762.7  Grenoble - Bus Station
# 1     NaN     XGE       None  102210.0      2687.3  Grenoble - Bus Station
# 2     NaN     XGE       None  102605.0      3646.9  Grenoble - Bus Station
# 3     NaN     XGE       None  104323.0        53.0  Grenoble - Bus Station
# 4     NaN     XGE       None  104424.0      3601.1  Grenoble - Bus Station
#
#                                        line_gtfs_ids        network  \
# 0  {'line_id': '4727592809', 'line_name': 'BlaBla...  BlaBlaCar Bus
# 1  {'line_id': '4727592809', 'line_name': 'BlaBla...  BlaBlaCar Bus
# 2  {'line_id': '4727592809', 'line_name': 'BlaBla...  BlaBlaCar Bus
# 3  {'line_id': '4727592809', 'line_name': 'BlaBla...  BlaBlaCar Bus
# 4  {'line_id': '4727592809', 'line_name': 'BlaBla...  BlaBlaCar Bus
#
#                          geometry source
# 0  POINT (636112.298 5651930.353)    TDG
# 1  POINT (636112.298 5651930.353)    TDG
# 2  POINT (636112.298 5651930.353)    TDG
# 3  POINT (636112.298 5651930.353)    TDG
# 4  POINT (636112.298 5651930.353)    TDG

# %%
tdg_mask = tdg_distances["distance_m"] == tdg_distances.groupby(["Id wp", "line_gtfs_ids"])[
    "distance_m"
].transform("min")
tdg_neareast_stops_by_line_gdf = tdg_stops_gdf[
    tdg_stops_gdf["gtfs_id"].isin(tdg_distances[tdg_mask]["gtfs_id"].unique())
]
print(
    f"{len(tdg_neareast_stops_by_line_gdf)} tdg bus stops are the nearest activity points for their bus line (on {len(tdg_stops_gdf)} bus stops)"
)
# Out:
# 2228 tdg bus stops are the nearest activity points for their bus line (on 15026 bus stops)

# %%
reachable_tdg_nb = len(tdg_distances[~pd.isnull(tdg_distances["gtfs_id"])]["Id wp"].unique())
print(f"{reachable_tdg_nb} activity point access are reachable with TDG data")
# Out:
# 471 activity point access are reachable with TDG data

# %% [markdown]
# # Visualize

# %% [markdown]
# ## All activity points

# %%
color_mapping = {"Outside departement": "gray", "Reachable": "green", "Unreachable": "purple"}
activity_gdf["color"] = activity_gdf["Category"].apply(lambda c: color_mapping[c])

# %%
reachable_nb = sum(activity_gdf["Category"] == "Reachable")
unreachable_nb = sum(activity_gdf["Category"] == "Unreachable")
outside_nb = sum(activity_gdf["Category"] == "Outside departement")
title_html = f"""
    <h4 style="position: fixed; top: 10px; left: 50px; z-index: 9999; background: rgba(255,255,255,0.8); padding: 6px 10px; margin: 0;">
    Points d'accès d'activité CampToCamp.<br>
    - {reachable_nb} points à moins de {distance_threshold_km}km d'un arrêt de bus (<span style=\"color: green\">vert</span>)<br>
    - {unreachable_nb} points à plus de {distance_threshold_km}km d'un arrêt de bus (<span style=\"color: purple\">violet</span>)<br>
    - {outside_nb} points en dehors du département (<span style=\"color: gray\">gris</span>)
    </h4>
"""

# %%
# Plot points with bus data far from distance_threshold m

# Add a base OSM map centered on Grenoble
m = folium.Map(
    location=[45.1885, 5.7245], zoom_start=9, tiles="OpenStreetMap", control_scale=True
)

# Add Waymarked Trails hiking layers
folium.TileLayer(tiles="WaymarkedTrails.hiking").add_to(m)

# Add Isère polygon
isere_latlon_coords = [
    (lat, lon)
    for lon, lat in area_gdf[area_gdf["code"] == isere_code]["geometry"]
    .values[0]
    .exterior.coords
]
folium.Polygon(
    locations=isere_latlon_coords,
    color="black",
    weight=3,
    fill_color="black",
    fill_opacity=0.25,
    fill=True,
).add_to(m)

# Add activity markers
columns_to_display = ["Id wp", "Name wp", "nbr_topo"]
folium.GeoJson(
    activity_gdf[columns_to_display + ["color", "geometry"]],
    zoom_on_click=True,
    marker=folium.Marker(icon=folium.Icon(icon="star")),
    tooltip=folium.GeoJsonTooltip(fields=columns_to_display),
    popup=folium.GeoJsonPopup(fields=columns_to_display),
    style_function=lambda x: {
        "markerColor": x["properties"]["color"],
    },
).add_to(m)

# Add title
m.get_root().html.add_child(folium.Element(title_html))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8c37658075e2ae5e95e07ca5d28bc6b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h4 style=&quot;position: fixed; top: 10px; left: 50px; z-index: 9999; background: rgba(255,255,255,0.8); padding: 6px 10px; margin: 0;&quot;&gt;
#     Points d&#x27;accès d&#x27;activité CampToCamp.&lt;br&gt;
#     - 479 points à moins de 5km d&#x27;un arrêt de bus (&lt;span style=&quot;color: green&quot;&gt;vert&lt;/span&gt;)&lt;br&gt;
#     - 35 points à plus de 5km d&#x27;un arrêt de bus (&lt;span style=&quot;color: purple&quot;&gt;violet&lt;/span&gt;)&lt;br&gt;
#     - 63 points en dehors du département (&lt;span style=&quot;color: gray&quot;&gt;gris&lt;/span&gt;)
#     &lt;/h4&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8c37658075e2ae5e95e07ca5d28bc6b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8c37658075e2ae5e95e07ca5d28bc6b = L.map(
#                 &quot;map_c8c37658075e2ae5e95e07ca5d28bc6b&quot;,
#                 {
#                     center: [45.1885, 5.7245],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_c8c37658075e2ae5e95e07ca5d28bc6b);
#
#
#
#
#
#             var tile_layer_9fb2e83749dfc33acbd6d73225377bb0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9fb2e83749dfc33acbd6d73225377bb0.addTo(map_c8c37658075e2ae5e95e07ca5d28bc6b);
#
#
#             var tile_layer_f09f654bdac3fbd13da740c1c59f9a2d = L.tileLayer(
#                 &quot;https://tile.waymarkedtrails.org/hiking/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map data: \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors | Map style: \u0026copy; \u003ca href=\&quot;https://waymarkedtrails.org\&quot;\u003ewaymarkedtrails.org\u003c/a\u003e (\u003ca href=\&quot;https://creativecommons.org/licenses/by-sa/3.0/\&quot;\u003eCC-BY-SA\u003c/a\u003e)&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f09f654bdac3fbd13da740c1c59f9a2d.addTo(map_c8c37658075e2ae5e95e07ca5d28bc6b);
#
#
#             var polygon_c36a2e8567e0c7c135e1804a9dcfc619 = L.polygon(
#                 [[45.61327, 5.62375], [45.61156, 5.62217], [45.60862, 5.62276], [45.60658, 5.62405], [45.60428, 5.62303], [45.60203, 5.62449], [45.6012, 5.62559], [45.59805, 5.63131], [45.58963, 5.63766], [45.58932, 5.63886], [45.58556, 5.64107], [45.58558, 5.64364], [45.58421, 5.64567], [45.57808, 5.64607], [45.57675, 5.64709], [45.57584, 5.6503], [45.57215, 5.65187], [45.5707, 5.65344], [45.56922, 5.65798], [45.56809, 5.65971], [45.56611, 5.66087], [45.56511, 5.66293], [45.56531, 5.66672], [45.56449, 5.66853], [45.56278, 5.66996], [45.56215, 5.67126], [45.56105, 5.67068], [45.55905, 5.67447], [45.55722, 5.67091], [45.55581, 5.6696], [45.55429, 5.67092], [45.55404, 5.67335], [45.55245, 5.67517], [45.55026, 5.67311], [45.54664, 5.67226], [45.54581, 5.67298], [45.54597, 5.67645], [45.54651, 5.67974], [45.54205, 5.68114], [45.54091, 5.68024], [45.54126, 5.6775], [45.54354, 5.67482], [45.54345, 5.67334], [45.53932, 5.67182], [45.53807, 5.66974], [45.53453, 5.67377], [45.53072, 5.67603], [45.52955, 5.6791], [45.52903, 5.68323], [45.52811, 5.6867], [45.52805, 5.69016], [45.

# %%
m.save("all_activity_points.html")

# %% [markdown]
# ## Filtered bus data with activities

# %%
import json

# %%
def list_to_str_with_br(l: list[str], line_number_limit: int = 10) -> str:
    list_to_process = l[:line_number_limit]
    if len(l) > line_number_limit:
        list_to_process += ["..."]
    return "<br>".join(list_to_process)

# %%
def get_tdg_line_names(lines: str) -> str:
    lines_json = "[" + lines.replace("'", '"') + "]"
    data = json.loads(lines_json)
    return list_to_str_with_br([d["line_name"] for d in data])

# %%
bus_stop_nb = {
    "TDG": len(tdg_neareast_stops_by_line_gdf),
    "OSM": len(osm_neareast_stops_by_line_gdf),
    "C2C": len(c2c_neareast_stops_by_line_gdf),
}
fields_by_source = {
    "TDG": ["gtfs_id", "name", "network", "line_gtfs_ids"],
    "OSM": ["osm_id", "name", "network", "lines"],
    "C2C": ["navitia_id", "name", "network", "lines"],
}
aliases_by_source = {
    "TDG": [f"<b>Arrêt de bus TDG</b><br>ID :", "Nom :", "Réseau :", "Lignes :"],
    "OSM": [f"<b>Arrêt de bus OSM</b><br>ID :", "Nom :", "Réseau :", "Lignes :"],
    "C2C": [f"<b>Arrêt de bus C2C</b><br>ID :", "Nom :", "Réseau :", "Lignes :"],
}
tdg_stops_to_plot = tdg_neareast_stops_by_line_gdf[
    fields_by_source["TDG"] + ["geometry"]
].copy()
tdg_stops_to_plot["line_gtfs_ids"] = tdg_neareast_stops_by_line_gdf["line_gtfs_ids"].apply(
    get_tdg_line_names
)
osm_stops_to_plot = osm_neareast_stops_by_line_gdf[
    fields_by_source["OSM"] + ["geometry"]
].copy()
osm_stops_to_plot["lines"] = osm_stops_to_plot["lines"].apply(list_to_str_with_br)
c2c_stops_to_plot = c2c_neareast_stops_by_line_gdf[
    fields_by_source["C2C"] + ["geometry"]
].copy()
c2c_stops_to_plot["lines"] = c2c_stops_to_plot["lines"].apply(list_to_str_with_br)
gdf_by_source = {"TDG": tdg_stops_to_plot, "OSM": osm_stops_to_plot, "C2C": c2c_stops_to_plot}

# %%
title_html = f"""
    <div style="position: fixed; top: 10px; left: 50px; z-index: 9999; background: rgba(255,255,255,0.8); padding: 6px 10px; margin: 0;">
        <h2>Couverture des points d'accès CampToCamp<br>desservis ou non par arrêts de bus<br>(selon sources associés : TDG, OSM, C2C)</h2>
        <h4>
            - {reachable_nb} points à moins de {distance_threshold_km}km d'un arrêt de bus (<span style=\"color: green\">vert</span>)<br>
            - {unreachable_nb} points à plus de {distance_threshold_km}km d'un arrêt de bus (<span style=\"color: purple\">violet</span>)<br>
            <br>
            - {reachable_tdg_nb} points accessibles avec les données TDG<br>
            - {reachable_osm_nb} points accessibles avec les données OSM<br>
            - {reachable_c2c_nb} points accessibles avec les données C2C<br>
        </h4>
    </div>
"""

# %%
# Add a base OSM map centered on Grenoble
m = folium.Map(
    location=[45.1885, 5.7245], zoom_start=9, tiles="OpenStreetMap", control_scale=True
)

# Add Waymarked Trails hiking layers
folium.TileLayer(tiles="WaymarkedTrails.hiking", control=False).add_to(m)

# Add Isère polygon
isere_latlon_coords = [
    (lat, lon)
    for lon, lat in area_gdf[area_gdf["code"] == isere_code]["geometry"]
    .values[0]
    .exterior.coords
]
folium.Polygon(
    locations=isere_latlon_coords,
    color="black",
    weight=3,
    fill_color="black",
    fill_opacity=0.25,
    fill=True,
).add_to(m)

# Add bus markers
source_to_id = {"TDG": "gtfs_id", "OSM": "osm_id", "C2C": "navitia_id"}
for source in ["TDG", "OSM", "C2C"]:
    fg = folium.FeatureGroup(name=f"Bus stops from {source} ({bus_stop_nb[source]})", show=True)
    fields = fields_by_source[source]
    aliases = aliases_by_source[source]
    folium.GeoJson(
        gdf_by_source[source][fields + ["geometry"]],
        zoom_on_click=True,
        marker=folium.Marker(icon=folium.Icon(icon="bus", prefix="fa", color="blue")),
        tooltip=folium.GeoJsonTooltip(fields=fields, aliases=aliases),
        popup=folium.GeoJsonPopup(fields=fields, aliases=aliases),
    ).add_to(fg)
    fg.add_to(m)


# Add activity markers
fg = folium.FeatureGroup(name="C2C activity access point", show=True)
aliases = [f"<b>Point d'accès d'activité</b><br>ID :", "Nom :", "Nombre de topos :"]
folium.GeoJson(
    activity_gdf[activity_gdf["Category"] != "Outside departement"][
        columns_to_display + ["color", "geometry"]
    ],
    zoom_on_click=True,
    marker=folium.Marker(icon=folium.Icon(icon="star")),
    tooltip=folium.GeoJsonTooltip(fields=columns_to_display, aliases=aliases),
    popup=folium.GeoJsonPopup(fields=columns_to_display, aliases=aliases),
    style_function=lambda x: {
        "markerColor": x["properties"]["color"],
    },
).add_to(fg)
fg.add_to(m)

# Add layer control to filter layers
folium.LayerControl(collapsed=False).add_to(m)

# Add title
m.get_root().html.add_child(folium.Element(title_html))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97a16a5b591898f03586651f64f08d22 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed; top: 10px; left: 50px; z-index: 9999; background: rgba(255,255,255,0.8); padding: 6px 10px; margin: 0;&quot;&gt;
#         &lt;h2&gt;Couverture des points d&#x27;accès CampToCamp&lt;br&gt;desservis ou non par arrêts de bus&lt;br&gt;(selon sources associés : TDG, OSM, C2C)&lt;/h2&gt;
#         &lt;h4&gt;
#             - 479 points à moins de 5km d&#x27;un arrêt de bus (&lt;span style=&quot;color: green&quot;&gt;vert&lt;/span&gt;)&lt;br&gt;
#             - 35 points à plus de 5km d&#x27;un arrêt de bus (&lt;span style=&quot;color: purple&quot;&gt;violet&lt;/span&gt;)&lt;br&gt;
#             &lt;br&gt;
#             - 471 points accessibles avec les données TDG&lt;br&gt;
#             - 435 points accessibles avec les données OSM&lt;br&gt;
#             - 411 points accessibles avec les données C2C&lt;

# %%
m.save(f"one_bus_by_line_and_source_at_distance_{distance_threshold_km}_km.html")
