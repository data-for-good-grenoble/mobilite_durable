# %% [markdown]
# 🚌 Projet MDM - Mobilité Durable en Montagne ⛰️
#
# *Author : Nicolas Grosjean*
#
# *Date : 13/09/2025*
#
# **Description :**
#
# This Jupyter Notebook analyses the OSM data

# %%
import geopandas as gpd
import pandas as pd

# %%
# %cd ../..
print("Working directory set to the root of the project")
# Out:
# D:\Documents\GitHub\mobilite_durable
# Working directory set to the root of the project

# %%
from src.processors.osm import OSMBusLinesProcessor, OSMBusStopsProcessor

# %%
def get_markdown_dtype(df: pd.DataFrame):
    markdown_table = "| Column | Dtype |\n|--------|-------|\n"
    for col in df.columns:
        non_null = df[col].count()
        dtype = df[col].dtype
        markdown_table += f"| {col} | {dtype} |\n"
    return markdown_table

# %%
bus_data = OSMBusStopsProcessor.fetch(reload_pipeline=False)
stops_df = pd.DataFrame(bus_data["features"])
stops_df.head()
# Out:
#       type                                           geometry  \
# 0  Feature  {'type': 'Point', 'coordinates': [5.7762176, 4...
# 1  Feature  {'type': 'Point', 'coordinates': [5.7423146, 4...
# 2  Feature  {'type': 'Point', 'coordinates': [5.6815922, 4...
# 3  Feature  {'type': 'Point', 'coordinates': [5.6627217, 4...
# 4  Feature  {'type': 'Point', 'coordinates': [5.604304, 45...
#
#                                           properties      id
# 0  {'bus': 'yes', 'highway': 'bus_stop', 'name': ...  135296
# 1  {'bus': 'yes', 'highway': 'bus_stop', 'name': ...  135930
# 2  {'bus': 'yes', 'description': 'Arrêt de régula...  136570
# 3  {'bus': 'yes', 'highway': 'bus_stop', 'name': ...  136597
# 4  {'bus': 'yes', 'highway': 'bus_stop', 'name': ...  137073

# %%
expanded = stops_df["properties"].apply(pd.Series)
expanded_stops_df = pd.concat([stops_df.drop(columns=["properties"]), expanded], axis=1)
expanded_stops_df[expanded_stops_df.columns[:10]].head()
# Out:
#       type                                           geometry      id  bus  \
# 0  Feature  {'type': 'Point', 'coordinates': [5.7762176, 4...  135296  yes
# 1  Feature  {'type': 'Point', 'coordinates': [5.7423146, 4...  135930  yes
# 2  Feature  {'type': 'Point', 'coordinates': [5.6815922, 4...  136570  yes
# 3  Feature  {'type': 'Point', 'coordinates': [5.6627217, 4...  136597  yes
# 4  Feature  {'type': 'Point', 'coordinates': [5.604304, 45...  137073  yes
#
#     highway                    name network public_transport wheelchair  \
# 0  bus_stop  Université - IUT-STAPS  M réso    stop_position        yes
# 1  bus_stop   Hôpital Couple Enfant  M réso    stop_position        yes
# 2  bus_stop              Cap des H'  M réso    stop_position        NaN
# 3  bus_stop  Place de la Libération  M réso    stop_position        yes
# 4  bus_stop             Centr'Alp 2  M réso    stop_position        NaN
#
#                             description
# 0                                   NaN
# 1                                   NaN
# 2  Arrêt de régulation, non commercial.
# 3                                   NaN
# 4                                   NaN

# %%
expanded_stops_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6791 entries, 0 to 6790
# Data columns (total 75 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   type                           6791 non-null   object
#  1   geometry                       6791 non-null   object
#  2   id                             6791 non-null   int64
#  3   bus                            5856 non-null   object
#  4   highway                        6791 non-null   object
#  5   name                           6378 non-null   object
#  6   network                        4829 non-null   object
#  7   public_transport               6758 non-null   object
#  8   wheelchair                     1256 non-null   object
#  9   description                    284 non-null    object
#  10  network:wikidata               413 non-null    object
#  11  fixme                          68 non-null     object
#  12  source                         165 non-null    object
#  13  shelter                        574 non-null    object
#  14  toilets                        1 non-null      object
#  15  bench                          389 non-null    object
#  16  bin                            187 non-null    object
#  17  lit                            112 non-null    object
#  18  tactile_paving                 190 non-null    object
#  19  mapillary                      283 non-null    object
#  20  survey:date                    264 non-null    object
#  21  departures_board               30 non-null     object
#  22  old_name                       39 non-null     object
#  23  pole                           55 non-null     object
#  24  amenity                        3 non-null      object
#  25  alt_name                       32 non-null     object
#  26  gtfs_id                        595 non-null    object
#  27  ref                            237 non-null    object
#  28  lwn_name                       28 non-null     object
#  29  network:type                   28 non-null     object
#  30  expected_lwn_route_relations   9 non-null      object
#  31  operator                       104 non-null    object
#  32  network:wikipedia              12 non-null     object
#  33  name:Autrans                   12 non-null     object
#  34  tram                           6 non-null      object
#  35  check_date:lit                 1 non-null      object
#  36  image                          16 non-null     object
#  37  level                          43 non-null     object
#  38  covered                        47 non-null     object
#  39  local_ref                      105 non-null    object
#  40  route_ref                      15 non-null     object
#  41  ref:station                    40 non-null     object
#  42  waste_basket                   4 non-null      object
#  43  ref:Chamrousse                 2 non-null      object
#  44  check_date:shelter             15 non-null     object
#  45  passenger_information_display  9 non-null      object
#  46  name:oc                        3 non-null      object
#  47  source:name:oc                 3 non-null      object
#  48  short_name                     18 non-null     object
#  49  name:signed                    8 non-null      object
#  50  operator:wikidata              11 non-null     object
#  51  information                    1 non-null      object
#  52  map_size                       1 non-null      object
#  53  map_type                       1 non-null      object
#  54  tourism                        1 non-null      object
#  55  not:network:wikidata           2 non-null      object
#  56  ref:FR:TCL                     3 non-null      object
#  57  note                           5 non-null      object
#  58  name:Transisère                1 non-null      object
#  59  traffic_calming                2 non-null      object
#  60  shelter_type                   1 non-null      object
#  61  check_date:bench               3 non-null      object
#  62  check_date:bin                 1 non-null      object
#  63  ref:FR:CG38                    8 non-null      object
#  64  source:date                    15 non-null     object
#  65  check_date                     1 non-null      object
#  66  website                        1 non-null      object
#  67  stop_id                        2 non-null      object
#  68  description:en                 1 non-null      object
#  69  wikimedia_commons              1 non-null      object
#  70  name:etymology:wikidata        2 non-null      object
#  71  noname                         2 non-null      object
#  72  construction                   2 non-null      object
#  73  start_date                     2 non-null      object
#  74  tourist_bus                    2 non-null      object
# dtypes: int64(1), object(74)
# memory usage: 3.9+ MB

# %%
print(
    get_markdown_dtype(expanded_stops_df[expanded_stops_df.columns[:10]]).replace(
        "object", "string"
    )
)
# Out:
# | Column | Dtype |
# |--------|-------|
# | type | string |
# | geometry | string |
# | id | int64 |
# | bus | string |
# | highway | string |
# | name | string |
# | network | string |
# | public_transport | string |
# | wheelchair | string |
# | description | string |

# %%
line_data = OSMBusLinesProcessor.fetch(reload_pipeline=False)
lines_df = pd.DataFrame(line_data)
lines_df.head()
# Out:
#         id                                               tags  \
# 0  2067887  {'colour': 'e53b1a', 'from': 'Gare de Saint-Cl...
# 1  2569190  {'colour': '#ee0064', 'from': 'Grenoble - Gare...
# 2  2569239  {'colour': '#ee0064', 'from': 'Aéroport Lyon S...
# 3  2920548  {'colour': '#1f72b9', 'description': 'Circule ...
# 4  2920549  {'colour': '#1f72b9', 'description': 'Circule ...
#
#                                                stops
# 0  [1659415935, 8874916309, 11146173165, 11146173...
# 1                [2617010911, 474827289, 6074566590]
# 2                [6074566590, 457759141, 2617010911]
# 3  [2299463674, 513946287, 513946283, 513946279, ...
# 4  [372746162, 451116247, 1829688368, 1829874475,...

# %%
expanded = lines_df["tags"].apply(pd.Series)
expanded_lines_df = pd.concat([lines_df.drop(columns=["tags"]), expanded], axis=1)
expanded_lines_df.head()
# Out:
#         id                                              stops   colour  \
# 0  2067887  [1659415935, 8874916309, 11146173165, 11146173...   e53b1a
# 1  2569190                [2617010911, 474827289, 6074566590]  #ee0064
# 2  2569239                [6074566590, 457759141, 2617010911]  #ee0064
# 3  2920548  [2299463674, 513946287, 513946283, 513946279, ...  #1f72b9
# 4  2920549  [372746162, 451116247, 1829688368, 1829874475,...  #1f72b9
#
#                                        from  \
# 0            Gare de Saint-Clair-Les-Roches
# 1                  Grenoble - Gare Routière
# 2  Aéroport Lyon Saint-Exupéry - Terminal 1
# 3              Saint Ismier - Bois Français
# 4              Grenoble - Verdun-Préfecture
#
#                                                 name    network  \
# 0  Ligne A : Gare de Saint-Clair-Les-Roches ⇒ Ron...        TPR
# 1  Ouibus 70 : Grenoble Gare Routière -> Aéroport...  BlaBlaBus
# 2  Ouibus 70 : Aéroport Lyon Saint-Exupéry -> Pla...  BlaBlaBus
# 3   15 : Bois Français => Grenoble (via Chenevières)     M réso
# 4   15 : Grenoble => Bois Français (via Chenevières)     M réso
#
#                         operator public_transport:version ref route  ...  \
# 0  Courriers Rhodaniens / Fayard                        2   A   bus  ...
# 1                  Faure Vercors                        2  70   bus  ...
# 2                  Faure Vercors                        2  70   bus  ...
# 3                            VFD                        2  15   bus  ...
# 4                            VFD                        2  15   bus  ...
#
#   charge  url comment fixme name:pt  bus check_date name:eu duration  \
# 0    NaN  NaN     NaN   NaN     NaN  NaN        NaN     NaN      NaN
# 1    NaN  NaN     NaN   NaN     NaN  NaN        NaN     NaN      NaN
# 2    NaN  NaN     NaN   NaN     NaN  NaN        NaN     NaN      NaN
# 3    NaN  NaN     NaN   NaN     NaN  NaN        NaN     NaN      NaN
# 4    NaN  NaN     NaN   NaN     NaN  NaN        NaN     NaN      NaN
#
#   public_transport
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 69 columns]

# %%
expanded_lines_df.loc[4, expanded_lines_df.columns[:25]]
# Out:
# id                                                                    2920549
# stops                       [372746162, 451116247, 1829688368, 1829874475,...
# colour                                                                #1f72b9
# from                                             Grenoble - Verdun-Préfecture
# name                         15 : Grenoble => Bois Français (via Chenevières)
# network                                                                M réso
# operator                                                                  VFD
# public_transport:version                                                    2
# ref                                                                        15
# route                                                                     bus
# to                                               Saint Ismier - Bois Français
# type                                                                    route
# via                                                      Domène - Chenevières
# network:wikidata                                                   Q131689044
# network:wikipedia                                                         NaN
# old_name                                                                  NaN
# opening_hours                                                         Jul-Aug
# description                                                     Circule l'été
# wheelchair                                                                yes
# old_ref                                                                   NaN
# not:network:wikidata                                                      NaN
# source                                                                    NaN
# gtfs_id                                                                   NaN
# roundtrip                                                                 NaN
# fee                                                                       NaN
# Name: 4, dtype: object

# %%
expanded_lines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867 entries, 0 to 1866
# Data columns (total 69 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1867 non-null   int64
#  1   stops                     1867 non-null   object
#  2   colour                    1440 non-null   object
#  3   from                      1863 non-null   object
#  4   name                      1867 non-null   object
#  5   network                   1861 non-null   object
#  6   operator                  1595 non-null   object
#  7   public_transport:version  1864 non-null   object
#  8   ref                       1863 non-null   object
#  9   route                     1867 non-null   object
#  10  to                        1863 non-null   object
#  11  type                      1867 non-null   object
#  12  via                       150 non-null    object
#  13  network:wikidata          1389 non-null   object
#  14  network:wikipedia         639 non-null    object
#  15  old_name                  11 non-null     object
#  16  opening_hours             237 non-null    object
#  17  description               73 non-null     object
#  18  wheelchair                209 non-null    object
#  19  old_ref                   93 non-null     object
#  20  not:network:wikidata      10 non-null     object
#  21  source                    18 non-null     object
#  22  gtfs_id                   335 non-null    object
#  23  roundtrip                 27 non-null     object
#  24  fee                       27 non-null     object
#  25  seasonal                  2 non-null      object
#  26  gtfs:feed                 2 non-null      object
#  27  gtfs:route_id             40 non-null     object
#  28  gtfs:shape_id             40 non-null     object
#  29  gtfs:trip_id:sample       2 non-null      object
#  30  network:guid              2 non-null      object
#  31  network:short             2 non-null      object
#  32  ref_trips                 2 non-null      object
#  33  website                   85 non-null     object
#  34  phone                     60 non-null     object
#  35  oneway                    2 non-null      object
#  36  interval                  15 non-null     object
#  37  interval:conditional      8 non-null      object
#  38  network:website           29 non-null     object
#  39  operator:wikidata         17 non-null     object
#  40  name:de                   92 non-null     object
#  41  name:fr                   89 non-null     object
#  42  name:it                   26 non-null     object
#  43  text_colour               34 non-null     object
#  44  operator:wikipedia        8 non-null      object
#  45  name:hr                   2 non-null      object
#  46  note                      19 non-null     object
#  47  name:ca                   17 non-null     object
#  48  name:en                   5 non-null      object
#  49  name:es                   20 non-null     object
#  50  description:ca            4 non-null      object
#  51  description:es            4 non-null      object
#  52  description:fr            4 non-null      object
#  53  description:de            1 non-null      object
#  54  on_demand                 2 non-null      object
#  55  segment                   2 non-null      object
#  56  owner                     2 non-null      object
#  57  ownership                 2 non-null      object
#  58  reservation               1 non-null      object
#  59  charge                    15 non-null     object
#  60  url                       20 non-null     object
#  61  comment                   1 non-null      object
#  62  fixme                     13 non-null     object
#  63  name:pt                   1 non-null      object
#  64  bus                       10 non-null     object
#  65  check_date                2 non-null      object
#  66  name:eu                   3 non-null      object
#  67  duration                  3 non-null      object
#  68  public_transport          1 non-null      object
# dtypes: int64(1), object(68)
# memory usage: 1006.6+ KB

# %%
print(
    get_markdown_dtype(expanded_lines_df[expanded_lines_df.columns[:25]]).replace(
        "object", "string"
    )
)
# Out:
# | Column | Dtype |
# |--------|-------|
# | id | int64 |
# | stops | string |
# | colour | string |
# | from | string |
# | name | string |
# | network | string |
# | operator | string |
# | public_transport:version | string |
# | ref | string |
# | route | string |
# | to | string |
# | type | string |
# | via | string |
# | network:wikidata | string |
# | network:wikipedia | string |
# | old_name | string |
# | opening_hours | string |
# | description | string |
# | wheelchair | string |
# | old_ref | string |
# | not:network:wikidata | string |
# | source | string |
# | gtfs_id | string |
# | roundtrip | string |
# | fee | string |
