# %% [markdown]
# 🚌 Projet MDM - Mobilité Durable en Montagne ⛰️
#
# *Author : Nicolas Grosjean*
#
# *Date : 13/09/2025*
#
# **Description :**
#
# This Jupyter Notebook analyses the OSM data

# %%
import geopandas as gpd
import pandas as pd

# %%
import os

os.chdir("../..")
print("Working directory set to the root of the project")
# Out:
# Working directory set to the root of the project

# %%
from src.processors.osm import OSMBusLinesProcessor, OSMBusStopsProcessor

# %%
def get_markdown_dtype(df: pd.DataFrame):
    markdown_table = "| Column | Dtype |\n|--------|-------|\n"
    for col in df.columns:
        non_null = df[col].count()
        dtype = df[col].dtype
        markdown_table += f"| {col} | {dtype} |\n"
    return markdown_table

# %%
stops_gdf = OSMBusStopsProcessor.fetch(reload_pipeline=False)
stops_gdf.head()
# Out:
#   gtfs_id navitia_id  osm_id                    name  \
# 0    None       None  135296  Université - IUT-STAPS
# 1    None       None  135930   Hôpital Couple Enfant
# 2    None       None  136570              Cap des H'
# 3    None       None  136597  Place de la Libération
# 4    None       None  137073             Centr'Alp 2
#
#                             description line_gtfs_ids  \
# 0                                  None            []
# 1                                  None            []
# 2  Arrêt de régulation, non commercial.            []
# 3                                  None            []
# 4                                  None            []
#
#                                         line_osm_ids network network_gtfs_id  \
# 0                                          [3922428]  M réso            None
# 1                                 [3333927, 3922430]  M réso            None
# 2                                                 []  M réso            None
# 3  [3031947, 3031948, 3044780, 3044781, 3923550, ...  M réso            None
# 4                                 [8671286, 8671287]  M réso            None
#
#                    geometry                                              other
# 0  POINT (5.77622 45.19738)  {'alt_name': None, 'amenity': None, 'bench': N...
# 1  POINT (5.74231 45.20065)  {'alt_name': None, 'amenity': None, 'bench': N...
# 2  POINT (5.68159 45.21695)  {'alt_name': None, 'amenity': None, 'bench': N...
# 3  POINT (5.66272 45.20707)  {'alt_name': None, 'amenity': None, 'bench': N...
# 4    POINT (5.6043 45.3198)  {'alt_name': None, 'amenity': None, 'bench': N...

# %%
stops_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 6806 entries, 0 to 6805
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   gtfs_id          595 non-null    object
#  1   navitia_id       0 non-null      object
#  2   osm_id           6806 non-null   int64
#  3   name             6806 non-null   object
#  4   description      276 non-null    object
#  5   line_gtfs_ids    6806 non-null   object
#  6   line_osm_ids     6806 non-null   object
#  7   network          4816 non-null   object
#  8   network_gtfs_id  0 non-null      object
#  9   geometry         6806 non-null   geometry
#  10  other            6806 non-null   object
# dtypes: geometry(1), int64(1), object(9)
# memory usage: 585.0+ KB

# %%
expanded = stops_gdf["other"].apply(pd.Series)
expanded_stops_gdf = pd.concat([stops_gdf.drop(columns=["other"]), expanded], axis=1)
expanded_stops_gdf[expanded_stops_gdf.columns[:10]].head()
# Out:
#   gtfs_id navitia_id  osm_id                    name  \
# 0    None       None  135296  Université - IUT-STAPS
# 1    None       None  135930   Hôpital Couple Enfant
# 2    None       None  136570              Cap des H'
# 3    None       None  136597  Place de la Libération
# 4    None       None  137073             Centr'Alp 2
#
#                             description line_gtfs_ids  \
# 0                                  None            []
# 1                                  None            []
# 2  Arrêt de régulation, non commercial.            []
# 3                                  None            []
# 4                                  None            []
#
#                                         line_osm_ids network network_gtfs_id  \
# 0                                          [3922428]  M réso            None
# 1                                 [3333927, 3922430]  M réso            None
# 2                                                 []  M réso            None
# 3  [3031947, 3031948, 3044780, 3044781, 3923550, ...  M réso            None
# 4                                 [8671286, 8671287]  M réso            None
#
#                    geometry
# 0  POINT (5.77622 45.19738)
# 1  POINT (5.74231 45.20065)
# 2  POINT (5.68159 45.21695)
# 3  POINT (5.66272 45.20707)
# 4    POINT (5.6043 45.3198)

# %%
expanded_stops_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 6806 entries, 0 to 6805
# Data columns (total 79 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   gtfs_id                        595 non-null    object
#  1   navitia_id                     0 non-null      object
#  2   osm_id                         6806 non-null   int64
#  3   name                           6806 non-null   object
#  4   description                    276 non-null    object
#  5   line_gtfs_ids                  6806 non-null   object
#  6   line_osm_ids                   6806 non-null   object
#  7   network                        4816 non-null   object
#  8   network_gtfs_id                0 non-null      object
#  9   geometry                       6806 non-null   geometry
#  10  alt_name                       32 non-null     object
#  11  amenity                        3 non-null      object
#  12  bench                          389 non-null    object
#  13  bin                            187 non-null    object
#  14  bus                            5873 non-null   object
#  15  check_date                     2 non-null      object
#  16  check_date:bench               3 non-null      object
#  17  check_date:bin                 1 non-null      object
#  18  check_date:lit                 1 non-null      object
#  19  check_date:shelter             15 non-null     object
#  20  check_date:tactile_paving      1 non-null      object
#  21  construction                   2 non-null      object
#  22  covered                        47 non-null     object
#  23  departures_board               30 non-null     object
#  24  description:en                 1 non-null      object
#  25  expected_lwn_route_relations   9 non-null      object
#  26  fixme                          68 non-null     object
#  27  highway                        6806 non-null   object
#  28  image                          16 non-null     object
#  29  information                    1 non-null      object
#  30  level                          43 non-null     object
#  31  lit                            112 non-null    object
#  32  local_ref                      105 non-null    object
#  33  lwn_name                       28 non-null     object
#  34  map_size                       1 non-null      object
#  35  map_type                       1 non-null      object
#  36  mapillary                      280 non-null    object
#  37  name:Autrans                   12 non-null     object
#  38  name:Transisère                1 non-null      object
#  39  name:etymology:wikidata        2 non-null      object
#  40  name:oc                        3 non-null      object
#  41  name:signed                    8 non-null      object
#  42  network:type                   28 non-null     object
#  43  network:wikidata               414 non-null    object
#  44  network:wikipedia              12 non-null     object
#  45  noname                         2 non-null      object
#  46  not:network:wikidata           2 non-null      object
#  47  note                           5 non-null      object
#  48  old_name                       39 non-null     object
#  49  operator                       127 non-null    object
#  50  operator:wikidata              11 non-null     object
#  51  passenger_information_display  9 non-null      object
#  52  pole                           53 non-null     object
#  53  public_transport               6773 non-null   object
#  54  ref                            237 non-null    object
#  55  ref:Chamrousse                 2 non-null      object
#  56  ref:FR:CG38                    8 non-null      object
#  57  ref:FR:TCL                     3 non-null      object
#  58  ref:station                    40 non-null     object
#  59  route_ref                      15 non-null     object
#  60  shelter                        574 non-null    object
#  61  shelter_type                   1 non-null      object
#  62  short_name                     18 non-null     object
#  63  source                         150 non-null    object
#  64  source:date                    15 non-null     object
#  65  source:name:oc                 3 non-null      object
#  66  start_date                     2 non-null      object
#  67  stop_id                        2 non-null      object
#  68  survey:date                    260 non-null    object
#  69  tactile_paving                 191 non-null    object
#  70  toilets                        1 non-null      object
#  71  tourism                        1 non-null      object
#  72  tourist_bus                    2 non-null      object
#  73  traffic_calming                2 non-null      object
#  74  tram                           6 non-null      object
#  75  waste_basket                   4 non-null      object
#  76  website                        1 non-null      object
#  77  wheelchair                     1248 non-null   object
#  78  wikimedia_commons              1 non-null      object
# dtypes: geometry(1), int64(1), object(77)
# memory usage: 4.1+ MB

# %%
print(
    get_markdown_dtype(expanded_stops_gdf[expanded_stops_gdf.columns[:10]]).replace(
        "object", "string"
    )
)
# Out:
# | Column | Dtype |
# |--------|-------|
# | gtfs_id | string |
# | navitia_id | string |
# | osm_id | int64 |
# | name | string |
# | description | string |
# | line_gtfs_ids | string |
# | line_osm_ids | string |
# | network | string |
# | network_gtfs_id | string |
# | geometry | geometry |

# %%
lines_df = OSMBusLinesProcessor.fetch(reload_pipeline=False)
lines_df.head()
# Out:
#   gtfs_id   osm_id                                               name  \
# 0    None  2067887  Ligne A : Gare de Saint-Clair-Les-Roches ⇒ Ron...
# 1    None  2569190  Ouibus 70 : Grenoble Gare Routière -> Aéroport...
# 2    None  2569239  Ouibus 70 : Aéroport Lyon Saint-Exupéry -> Pla...
# 3    None  2920548   15 : Bois Français => Grenoble (via Chenevières)
# 4    None  2920549   15 : Grenoble => Bois Français (via Chenevières)
#
#                               from_location  \
# 0            Gare de Saint-Clair-Les-Roches
# 1                  Grenoble - Gare Routière
# 2  Aéroport Lyon Saint-Exupéry - Terminal 1
# 3              Saint Ismier - Bois Français
# 4              Grenoble - Verdun-Préfecture
#
#                                          to    network network_gtfs_id  \
# 0                         Rond-point Chanas        TPR            None
# 1  Aéroport Lyon Saint-Exupéry - Terminal 1  BlaBlaBus            None
# 2                  Grenoble - Gare routière  BlaBlaBus            None
# 3              Grenoble - Verdun-Préfecture     M réso            None
# 4              Saint Ismier - Bois Français     M réso            None
#
#   network_wikidata                       operator   colour text_colour  \
# 0             None  Courriers Rhodaniens / Fayard   e53b1a        None
# 1         Q1653380                  Faure Vercors  #ee0064        None
# 2         Q1653380                  Faure Vercors  #ee0064        None
# 3       Q131689044                            VFD  #1f72b9        None
# 4       Q131689044                            VFD  #1f72b9        None
#
#   stop_gtfs_ids                                      stops_osm_ids  school  \
# 0            []  [1659415935, 8874916309, 11146173165, 11146173...   False
# 1            []                [2617010911, 474827289, 6074566590]   False
# 2            []                [6074566590, 457759141, 2617010911]   False
# 3            []  [2299463674, 513946287, 513946283, 513946279, ...   False
# 4            []  [372746162, 451116247, 1829688368, 1829874475,...   False
#
#   geometry                                              other
# 0     None  {'charge': None, 'check_date': None, 'comment'...
# 1     None  {'charge': None, 'check_date': None, 'comment'...
# 2     None  {'charge': None, 'check_date': None, 'comment'...
# 3     None  {'charge': None, 'check_date': None, 'comment'...
# 4     None  {'charge': None, 'check_date': None, 'comment'...

# %%
lines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1874 entries, 0 to 1873
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gtfs_id           335 non-null    object
#  1   osm_id            1874 non-null   int64
#  2   name              1874 non-null   object
#  3   from_location     1870 non-null   object
#  4   to                1870 non-null   object
#  5   network           1868 non-null   object
#  6   network_gtfs_id   0 non-null      object
#  7   network_wikidata  1487 non-null   object
#  8   operator          1613 non-null   object
#  9   colour            1445 non-null   object
#  10  text_colour       34 non-null     object
#  11  stop_gtfs_ids     1874 non-null   object
#  12  stops_osm_ids     1874 non-null   object
#  13  school            1874 non-null   bool
#  14  geometry          0 non-null      object
#  15  other             1874 non-null   object
# dtypes: bool(1), int64(1), object(14)
# memory usage: 221.6+ KB

# %%
expanded = lines_df["other"].apply(pd.Series)
expanded_lines_df = pd.concat([lines_df.drop(columns=["other"]), expanded], axis=1)
expanded_lines_df.head()
# Out:
#   gtfs_id   osm_id                                               name  \
# 0    None  2067887  Ligne A : Gare de Saint-Clair-Les-Roches ⇒ Ron...
# 1    None  2569190  Ouibus 70 : Grenoble Gare Routière -> Aéroport...
# 2    None  2569239  Ouibus 70 : Aéroport Lyon Saint-Exupéry -> Pla...
# 3    None  2920548   15 : Bois Français => Grenoble (via Chenevières)
# 4    None  2920549   15 : Grenoble => Bois Français (via Chenevières)
#
#                               from_location  \
# 0            Gare de Saint-Clair-Les-Roches
# 1                  Grenoble - Gare Routière
# 2  Aéroport Lyon Saint-Exupéry - Terminal 1
# 3              Saint Ismier - Bois Français
# 4              Grenoble - Verdun-Préfecture
#
#                                          to    network network_gtfs_id  \
# 0                         Rond-point Chanas        TPR            None
# 1  Aéroport Lyon Saint-Exupéry - Terminal 1  BlaBlaBus            None
# 2                  Grenoble - Gare routière  BlaBlaBus            None
# 3              Grenoble - Verdun-Préfecture     M réso            None
# 4              Saint Ismier - Bois Français     M réso            None
#
#   network_wikidata                       operator   colour  ... roundtrip  \
# 0             None  Courriers Rhodaniens / Fayard   e53b1a  ...      None
# 1         Q1653380                  Faure Vercors  #ee0064  ...      None
# 2         Q1653380                  Faure Vercors  #ee0064  ...      None
# 3       Q131689044                            VFD  #1f72b9  ...      None
# 4       Q131689044                            VFD  #1f72b9  ...      None
#
#   route seasonal  segment source   type   url  \
# 0   bus     None     None   None  route  None
# 1   bus     None     None   None  route  None
# 2   bus     None     None   None  route  None
# 3   bus     None     None   None  route  None
# 4   bus     None     None   None  route  None
#
#                                   via website wheelchair
# 0  Le Péage de Roussillon - Gare SNCF    None       None
# 1              Place de la résistance    None       None
# 2              Place de la Résistance    None       None
# 3                Domène - Chenevières    None        yes
# 4                Domène - Chenevières    None        yes
#
# [5 rows x 72 columns]

# %%
expanded_lines_df.loc[4, expanded_lines_df.columns[:25]]
# Out:
# gtfs_id                                                          None
# osm_id                                                        2920549
# name                 15 : Grenoble => Bois Français (via Chenevières)
# from_location                            Grenoble - Verdun-Préfecture
# to                                       Saint Ismier - Bois Français
# network                                                        M réso
# network_gtfs_id                                                  None
# network_wikidata                                           Q131689044
# operator                                                          VFD
# colour                                                        #1f72b9
# text_colour                                                      None
# stop_gtfs_ids                                                      []
# stops_osm_ids       [372746162, 451116247, 1829688368, 1829874475,...
# school                                                          False
# geometry                                                         None
# charge                                                           None
# check_date                                                       None
# comment                                                          None
# description                                             Circule l'été
# description:ca                                                   None
# description:de                                                   None
# description:es                                                   None
# description:fr                                                   None
# duration                                                         None
# fee                                                              None
# Name: 4, dtype: object

# %%
expanded_lines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1874 entries, 0 to 1873
# Data columns (total 72 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gtfs_id                   335 non-null    object
#  1   osm_id                    1874 non-null   int64
#  2   name                      1874 non-null   object
#  3   from_location             1870 non-null   object
#  4   to                        1870 non-null   object
#  5   network                   1868 non-null   object
#  6   network_gtfs_id           0 non-null      object
#  7   network_wikidata          1487 non-null   object
#  8   operator                  1613 non-null   object
#  9   colour                    1445 non-null   object
#  10  text_colour               34 non-null     object
#  11  stop_gtfs_ids             1874 non-null   object
#  12  stops_osm_ids             1874 non-null   object
#  13  school                    1874 non-null   bool
#  14  geometry                  0 non-null      object
#  15  charge                    15 non-null     object
#  16  check_date                2 non-null      object
#  17  comment                   1 non-null      object
#  18  description               73 non-null     object
#  19  description:ca            4 non-null      object
#  20  description:de            1 non-null      object
#  21  description:es            4 non-null      object
#  22  description:fr            4 non-null      object
#  23  duration                  3 non-null      object
#  24  fee                       27 non-null     object
#  25  fixme                     13 non-null     object
#  26  gtfs:feed                 2 non-null      object
#  27  gtfs:route_id             40 non-null     object
#  28  gtfs:shape_id             40 non-null     object
#  29  gtfs:trip_id:sample       2 non-null      object
#  30  interval                  15 non-null     object
#  31  interval:conditional      8 non-null      object
#  32  name:ca                   17 non-null     object
#  33  name:de                   92 non-null     object
#  34  name:en                   5 non-null      object
#  35  name:es                   20 non-null     object
#  36  name:eu                   3 non-null      object
#  37  name:fr                   89 non-null     object
#  38  name:hr                   2 non-null      object
#  39  name:it                   26 non-null     object
#  40  name:pt                   1 non-null      object
#  41  network:guid              2 non-null      object
#  42  network:short             2 non-null      object
#  43  network:website           29 non-null     object
#  44  network:wikipedia         639 non-null    object
#  45  not:network:wikidata      10 non-null     object
#  46  note                      19 non-null     object
#  47  old_name                  11 non-null     object
#  48  old_ref                   93 non-null     object
#  49  on_demand                 2 non-null      object
#  50  oneway                    2 non-null      object
#  51  opening_hours             237 non-null    object
#  52  operator:wikidata         17 non-null     object
#  53  operator:wikipedia        8 non-null      object
#  54  owner                     2 non-null      object
#  55  ownership                 2 non-null      object
#  56  phone                     60 non-null     object
#  57  public_transport          1 non-null      object
#  58  public_transport:version  1872 non-null   object
#  59  ref                       1870 non-null   object
#  60  ref_trips                 2 non-null      object
#  61  reservation               1 non-null      object
#  62  roundtrip                 26 non-null     object
#  63  route                     1874 non-null   object
#  64  seasonal                  2 non-null      object
#  65  segment                   2 non-null      object
#  66  source                    18 non-null     object
#  67  type                      1874 non-null   object
#  68  url                       20 non-null     object
#  69  via                       150 non-null    object
#  70  website                   85 non-null     object
#  71  wheelchair                212 non-null    object
# dtypes: bool(1), int64(1), object(70)
# memory usage: 1.0+ MB

# %%
print(
    get_markdown_dtype(expanded_lines_df[expanded_lines_df.columns[:25]]).replace(
        "object", "string"
    )
)
# Out:
# | Column | Dtype |
# |--------|-------|
# | gtfs_id | string |
# | osm_id | int64 |
# | name | string |
# | from_location | string |
# | to | string |
# | network | string |
# | network_gtfs_id | string |
# | network_wikidata | string |
# | operator | string |
# | colour | string |
# | text_colour | string |
# | stop_gtfs_ids | string |
# | stops_osm_ids | string |
# | school | bool |
# | geometry | string |
# | charge | string |
# | check_date | string |
# | comment | string |
# | description | string |
# | description:ca | string |
# | description:de | string |
# | description:es | string |
# | description:fr | string |
# | duration | string |
# | fee | string |

# %%
lines_gdf = OSMBusLinesProcessor.fetch(
    reload_pipeline=False,
    fetch_api_kwargs={"fetch_geometry": True},
    fetch_input_kwargs={"fetch_geometry": True},
    fetch_output_kwargs={"fetch_geometry": True},
)
lines_gdf.head()
# Out:
#   gtfs_id   osm_id                                               name  \
# 0    None  2067887  Ligne A : Gare de Saint-Clair-Les-Roches ⇒ Ron...
# 1    None  2569190  Ouibus 70 : Grenoble Gare Routière -> Aéroport...
# 2    None  2569239  Ouibus 70 : Aéroport Lyon Saint-Exupéry -> Pla...
# 3    None  2920548   15 : Bois Français => Grenoble (via Chenevières)
# 4    None  2920549   15 : Grenoble => Bois Français (via Chenevières)
#
#                               from_location  \
# 0            Gare de Saint-Clair-Les-Roches
# 1                  Grenoble - Gare Routière
# 2  Aéroport Lyon Saint-Exupéry - Terminal 1
# 3              Saint Ismier - Bois Français
# 4              Grenoble - Verdun-Préfecture
#
#                                          to    network network_gtfs_id  \
# 0                         Rond-point Chanas        TPR            None
# 1  Aéroport Lyon Saint-Exupéry - Terminal 1  BlaBlaBus            None
# 2                  Grenoble - Gare routière  BlaBlaBus            None
# 3              Grenoble - Verdun-Préfecture     M réso            None
# 4              Saint Ismier - Bois Français     M réso            None
#
#   network_wikidata                       operator   colour text_colour  \
# 0             None  Courriers Rhodaniens / Fayard   e53b1a        None
# 1         Q1653380                  Faure Vercors  #ee0064        None
# 2         Q1653380                  Faure Vercors  #ee0064        None
# 3       Q131689044                            VFD  #1f72b9        None
# 4       Q131689044                            VFD  #1f72b9        None
#
#   stop_gtfs_ids                                      stops_osm_ids  school  \
# 0            []  [1659415935, 8874916309, 11146173165, 11146173...   False
# 1            []                [2617010911, 474827289, 6074566590]   False
# 2            []                [6074566590, 457759141, 2617010911]   False
# 3            []  [2299463674, 513946287, 513946283, 513946279, ...   False
# 4            []  [372746162, 451116247, 1829688368, 1829874475,...   False
#
#                                             geometry  \
# 0  GEOMETRYCOLLECTION (POLYGON ((4.81468 45.34524...
# 1  MULTILINESTRING ((5.71428 45.19292, 5.71419 45...
# 2  MULTILINESTRING ((5.07924 45.71927, 5.07917 45...
# 3  GEOMETRYCOLLECTION (POLYGON ((5.78695 45.18137...
# 4  GEOMETRYCOLLECTION (POLYGON ((5.78695 45.18137...
#
#                                                other
# 0  {'charge': None, 'check_date': None, 'comment'...
# 1  {'charge': None, 'check_date': None, 'comment'...
# 2  {'charge': None, 'check_date': None, 'comment'...
# 3  {'charge': None, 'check_date': None, 'comment'...
# 4  {'charge': None, 'check_date': None, 'comment'...

# %%
lines_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1874 entries, 0 to 1873
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gtfs_id           335 non-null    object
#  1   osm_id            1874 non-null   int64
#  2   name              1874 non-null   object
#  3   from_location     1870 non-null   object
#  4   to                1870 non-null   object
#  5   network           1868 non-null   object
#  6   network_gtfs_id   0 non-null      object
#  7   network_wikidata  1487 non-null   object
#  8   operator          1613 non-null   object
#  9   colour            1445 non-null   object
#  10  text_colour       34 non-null     object
#  11  stop_gtfs_ids     1874 non-null   object
#  12  stops_osm_ids     1874 non-null   object
#  13  school            1874 non-null   bool
#  14  geometry          1874 non-null   geometry
#  15  other             1874 non-null   object
# dtypes: bool(1), geometry(1), int64(1), object(13)
# memory usage: 221.6+ KB

# %%
c4_gdf = lines_gdf[lines_gdf["name"].apply(lambda s: "C4" in s)]
print("Display Bus line C4")
c4_gdf.explore()
# Out:
# Display Bus line C4
# /data/hdd/Documents/GitHub/mobilite_durable/.venv/lib/python3.13/site-packages/folium/features.py:1204: UserWarning: GeoJsonTooltip is not configured to render for GeoJson GeometryCollection geometries. Please consider reworking these features: [{'gtfs_id': None, 'osm_id': 3921468, 'name': 'C4 : Eybens => Grenoble', 'from_location': 'Eybens - Le Verderet', 'to': 'Grenoble - Victor Hugo', 'network': 'M réso', 'network_gtfs_id': None, 'network_wikidata': 'Q131689044', 'operator': None, 'colour': '#f5d24d', 'text_colour': None, 'stop_gtfs_ids': '[]', 'stops_osm_ids': '[ 498506887  498506905  498506914  498506923  498506933  498506942\n  498506945  498506961  498506970  498506980 2480878612  498506998\n  498507007  457759176 7054915201 1828989762 4788103942]', 'school': False, 'other': "{'charge': None, 'check_date': None, 'comment': None, 'description': None, 'description:ca': None, 'description:de': None, 'description:es': None, 'description:fr': None, 'duration': None, 'fee': None, 'fixme': None, 'gtfs:feed': None, 'gtfs:route_id': None, 'gtfs:shape_id': None, 'gtfs:trip_id:sample': None, 'interval': None, 'interval:conditional': None, 'name:ca': None, 'name:de': None, 'name:en': None, 'name:es': None, 'name:eu': None, 'name:fr': None, 'name:hr': None, 'name:it': None, 'name:pt': None, 'network:guid': None, 'network:short': None, 'network:website': None, 'network:wikipedia': None, 'not:network:wikidata': None, 'note': None, 'old_name': None, 'old_ref': None, 'on_demand': None, 'oneway': None, 'opening_hours': 'Mo-Sa 00:00-00:45,05:30-24:00; Su 00:00-00:45,06:00-24:00', 'operator:wikidata': None, 'operator:wikipedia': None, 'owner': None, 'ownership': None, 'phone': None, 'public_transport': None, 'public_transport:version': '2', 'ref': 'C4', 'ref_trips': None, 'reservation': None, 'roundtrip': None, 'route': 'bus', 'seasonal': None, 'segment': None, 'source': None, 'type': 'route', 'url': None, 'via': None, 'website': None, 'wheelchair': 'yes'}"}, {'gtfs_id': None, 'osm_id': 3921469, 'name': 'C4 : Grenoble => Eybens', 'from_location': 'Grenoble - Victor Hugo', 'to': 'Eybens - Le Verderet', 'network': 'M réso', 'network_gtfs_id': None, 'network_wikidata': 'Q131689044', 'operator': 'M Tag Eybens', 'colour': '#f5d24d', 'text_colour': None, 'stop_gtfs_ids': '[]', 'stops_osm_ids': '[4788103942 6427554261 1829590508  457759175  498507007  498506993\n 3861199702  498506980  498506966  498506955  498506951  498506937\n  498506928  498506919  498506910  498506905  498506894]', 'school': False, 'other': "{'charge': None, 'check_date': None, 'comment': None, 'description': None, 'description:ca': None, 'description:de': None, 'description:es': None, 'description:fr': None, 'duration': None, 'fee': None, 'fixme': None, 'gtfs:feed': None, 'gtfs:route_id': None, 'gtfs:shape_id': None, 'gtfs:trip_id:sample': None, 'interval': None, 'interval:conditional': None, 'name:ca': None, 'name:de': None, 'name:en': None, 'name:es': None, 'name:eu': None, 'name:fr': None, 'name:hr': None, 'name:it': None, 'name:pt': None, 'network:guid': None, 'network:short': None, 'network:website': None, 'network:wikipedia': None, 'not:network:wikidata': None, 'note': None, 'old_name': None, 'old_ref': None, 'on_demand': None, 'oneway': None, 'opening_hours': 'Mo-Sa 00:00-00:45,05:30-24:00; Su 00:00-00:45,06:00-24:00', 'operator:wikidata': None, 'operator:wikipedia': None, 'owner': None, 'ownership': None, 'phone': None, 'public_transport': None, 'public_transport:version': '2', 'ref': 'C4', 'ref_trips': None, 'reservation': None, 'roundtrip': None, 'route': 'bus', 'seasonal': None, 'segment': None, 'source': None, 'type': 'route', 'url': None, 'via': None, 'website': None, 'wheelchair': 'yes'}"}] to MultiPolygon for full functionality.
# https://tools.ietf.org/html/rfc7946#page-9
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9138c55f3ec1997cbd33f28fec145176 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9138c55f3ec1997cbd33f28fec145176&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9138c55f3ec1997cbd33f28fec145176 = L.map(
#                 &quot;map_9138c55f3ec1997cbd33f28fec145176&quot;,
#                 {
#                     center: [45.16787185, 5.7400924],
#                     crs: L.CRS.Simple,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_9138c55f3ec1997cbd33f28fec145176);
#
#
#
#
#
#             map_9138c55f3ec1997cbd33f28fec145176.fitBounds(
#                 [[45.146865, 5.7250498], [45.1888787, 5.755135]],
#                 {}
#             );
#
#
#         function geo_json_4385bb302442eb6da1dadf1d5daec860_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_4385bb302442eb6da1dadf1d5daec860_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4385bb302442eb6da1dadf1d5daec860_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_4385bb302442eb6da1dadf1d5daec860_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_4385bb302442eb6da1dadf1d5daec860_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_4385bb302442eb6da1dadf1d5daec860.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_4385bb302442eb6da1dadf1d5daec860_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_4385bb302442eb6da1dadf1d5daec860 = L.geoJson(null, {
#                 onEachFeature: geo_json_4385bb302442eb6da1dadf1d5daec860_onEachFeature,
#
#                 style: geo_json_4385bb302442eb6da1dadf1d5daec860_styler,
#                 pointToLayer: geo_json_4385bb302442eb6da1dadf1d5daec860_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_4385bb302442eb6da1dadf1d5daec860_add (data) {
#             geo_json_4385bb302442eb6da1dadf1d5daec860
#                 .addData(data);
#         }
#             geo_json_4385bb302442eb6da1dadf1d5daec860_add({&quot;bbox&quot;: [5.7250498, 45.146865, 5.755135, 45.1888787], &quot;features&quot;: [{&quot;bbox&quot;: [5.7250498, 45.146865, 5.755135, 45.1888787], &quot;geometry&quot;: {&quot;geometries&quot;: [{&quot;coordinates&quot;: [[[5.7443512, 45.1615976], [5.7443282, 45.1615803], [5.7443011, 45.1615662], [5.7442709, 45.1615557], [5.7442385, 45.1615492], [5.744205, 45.1615469], [5.7441572, 45.161551], [5.7441124, 45.1615636], [5.7440736, 45.1615837], [5.7440426, 45.1616112], [5.7440229, 45.1616434], [5.7440159, 45.1616782], [5.7440221, 45.161713], [5.7440391, 45.1617429], [5.7440657, 45.161769], [5.7441025, 45.1617907], [5.7441397, 45.1618036], [5.7441801, 45.1618105], [5.7442216, 45.1618109], [5.7442622, 45.1618049], [5.7443034, 45.1617913], [5.7443386, 45.1617711], [5.7443628, 45.1617492], [5.74438, 45.1617242], [5.7443894, 45.1616973], [5.7443907, 45.1616696], [5.744383, 45.1616405], [5.7443696, 45.1616175], [5.7443512, 45.1615976]]], &quot;type&quot;: &quot;Polygon&quot;}, {&quot;coordinates&quot;: [[5.7545424, 45.1469292], [5.7546741, 45.1469162], [5.755135, 45.146865]], &quot;type&quot;: &quot;LineString&quot;}, {&quot;coordinates&quot;: [[5.7544247, 45.1469386], [5.7545424, 45.1469292]], &quot
