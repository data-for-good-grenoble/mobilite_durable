# %% [markdown]
# 🚌 Projet MDM - Mobilité Durable en Montagne ⛰️
#
# *Author : Nicolas Grosjean*
#
# *Date : 13/09/2025*
#
# **Description :**
#
# This Jupyter Notebook analyses the OSM data

# %%
import geopandas as gpd
import pandas as pd

# %%
# %cd ../..
print("Working directory set to the root of the project")
# Out:
# D:\Documents\GitHub\mobilite_durable
# Working directory set to the root of the project

# %%
from src.processors.osm import OSMBusLinesProcessor, OSMBusStopsProcessor

# %%
def get_markdown_dtype(df: pd.DataFrame):
    markdown_table = "| Column | Dtype |\n|--------|-------|\n"
    for col in df.columns:
        non_null = df[col].count()
        dtype = df[col].dtype
        markdown_table += f"| {col} | {dtype} |\n"
    return markdown_table

# %%
stops_gdf = OSMBusStopsProcessor.fetch(reload_pipeline=False)
stops_gdf.head()
# Out:
#   gtfs_id navitia_id  osm_id                    name  \
# 0    None       None  135296  Université - IUT-STAPS
# 1    None       None  135930   Hôpital Couple Enfant
# 2    None       None  136570              Cap des H'
# 3    None       None  136597  Place de la Libération
# 4    None       None  137073             Centr'Alp 2
#
#                             description line_gtfs_ids line_osm_ids  \
# 0                                  None            []           []
# 1                                  None            []           []
# 2  Arrêt de régulation, non commercial.            []           []
# 3                                  None            []           []
# 4                                  None            []           []
#
#                    geometry                                              other
# 0  POINT (5.77622 45.19738)  {'alt_name': None, 'amenity': None, 'bench': N...
# 1  POINT (5.74231 45.20065)  {'alt_name': None, 'amenity': None, 'bench': N...
# 2  POINT (5.68159 45.21695)  {'alt_name': None, 'amenity': None, 'bench': N...
# 3  POINT (5.66272 45.20707)  {'alt_name': None, 'amenity': None, 'bench': N...
# 4    POINT (5.6043 45.3198)  {'alt_name': None, 'amenity': None, 'bench': N...

# %%
stops_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 6792 entries, 0 to 6791
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gtfs_id        595 non-null    object
#  1   navitia_id     0 non-null      object
#  2   osm_id         6792 non-null   int64
#  3   name           6792 non-null   object
#  4   description    284 non-null    object
#  5   line_gtfs_ids  6792 non-null   object
#  6   line_osm_ids   6792 non-null   object
#  7   geometry       6792 non-null   geometry
#  8   other          6792 non-null   object
# dtypes: geometry(1), int64(1), object(7)
# memory usage: 477.7+ KB

# %%
expanded = stops_gdf["other"].apply(pd.Series)
expanded_stops_gdf = pd.concat([stops_gdf.drop(columns=["other"]), expanded], axis=1)
expanded_stops_gdf[expanded_stops_gdf.columns[:10]].head()
# Out:
#   gtfs_id navitia_id  osm_id                    name  \
# 0    None       None  135296  Université - IUT-STAPS
# 1    None       None  135930   Hôpital Couple Enfant
# 2    None       None  136570              Cap des H'
# 3    None       None  136597  Place de la Libération
# 4    None       None  137073             Centr'Alp 2
#
#                             description line_gtfs_ids line_osm_ids  \
# 0                                  None            []           []
# 1                                  None            []           []
# 2  Arrêt de régulation, non commercial.            []           []
# 3                                  None            []           []
# 4                                  None            []           []
#
#                    geometry alt_name amenity
# 0  POINT (5.77622 45.19738)     None    None
# 1  POINT (5.74231 45.20065)     None    None
# 2  POINT (5.68159 45.21695)     None    None
# 3  POINT (5.66272 45.20707)     None    None
# 4    POINT (5.6043 45.3198)     None    None

# %%
expanded_stops_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6791 entries, 0 to 6790
# Data columns (total 75 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   type                           6791 non-null   object
#  1   geometry                       6791 non-null   object
#  2   id                             6791 non-null   int64
#  3   bus                            5856 non-null   object
#  4   highway                        6791 non-null   object
#  5   name                           6378 non-null   object
#  6   network                        4829 non-null   object
#  7   public_transport               6758 non-null   object
#  8   wheelchair                     1256 non-null   object
#  9   description                    284 non-null    object
#  10  network:wikidata               413 non-null    object
#  11  fixme                          68 non-null     object
#  12  source                         165 non-null    object
#  13  shelter                        574 non-null    object
#  14  toilets                        1 non-null      object
#  15  bench                          389 non-null    object
#  16  bin                            187 non-null    object
#  17  lit                            112 non-null    object
#  18  tactile_paving                 190 non-null    object
#  19  mapillary                      283 non-null    object
#  20  survey:date                    264 non-null    object
#  21  departures_board               30 non-null     object
#  22  old_name                       39 non-null     object
#  23  pole                           55 non-null     object
#  24  amenity                        3 non-null      object
#  25  alt_name                       32 non-null     object
#  26  gtfs_id                        595 non-null    object
#  27  ref                            237 non-null    object
#  28  lwn_name                       28 non-null     object
#  29  network:type                   28 non-null     object
#  30  expected_lwn_route_relations   9 non-null      object
#  31  operator                       104 non-null    object
#  32  network:wikipedia              12 non-null     object
#  33  name:Autrans                   12 non-null     object
#  34  tram                           6 non-null      object
#  35  check_date:lit                 1 non-null      object
#  36  image                          16 non-null     object
#  37  level                          43 non-null     object
#  38  covered                        47 non-null     object
#  39  local_ref                      105 non-null    object
#  40  route_ref                      15 non-null     object
#  41  ref:station                    40 non-null     object
#  42  waste_basket                   4 non-null      object
#  43  ref:Chamrousse                 2 non-null      object
#  44  check_date:shelter             15 non-null     object
#  45  passenger_information_display  9 non-null      object
#  46  name:oc                        3 non-null      object
#  47  source:name:oc                 3 non-null      object
#  48  short_name                     18 non-null     object
#  49  name:signed                    8 non-null      object
#  50  operator:wikidata              11 non-null     object
#  51  information                    1 non-null      object
#  52  map_size                       1 non-null      object
#  53  map_type                       1 non-null      object
#  54  tourism                        1 non-null      object
#  55  not:network:wikidata           2 non-null      object
#  56  ref:FR:TCL                     3 non-null      object
#  57  note                           5 non-null      object
#  58  name:Transisère                1 non-null      object
#  59  traffic_calming                2 non-null      object
#  60  shelter_type                   1 non-null      object
#  61  check_date:bench               3 non-null      object
#  62  check_date:bin                 1 non-null      object
#  63  ref:FR:CG38                    8 non-null      object
#  64  source:date                    15 non-null     object
#  65  check_date                     1 non-null      object
#  66  website                        1 non-null      object
#  67  stop_id                        2 non-null      object
#  68  description:en                 1 non-null      object
#  69  wikimedia_commons              1 non-null      object
#  70  name:etymology:wikidata        2 non-null      object
#  71  noname                         2 non-null      object
#  72  construction                   2 non-null      object
#  73  start_date                     2 non-null      object
#  74  tourist_bus                    2 non-null      object
# dtypes: int64(1), object(74)
# memory usage: 3.9+ MB

# %%
print(
    get_markdown_dtype(expanded_stops_gdf[expanded_stops_gdf.columns[:10]]).replace(
        "object", "string"
    )
)
# Out:
# | Column | Dtype |
# |--------|-------|
# | gtfs_id | string |
# | navitia_id | string |
# | osm_id | int64 |
# | name | string |
# | description | string |
# | line_gtfs_ids | string |
# | line_osm_ids | string |
# | geometry | geometry |
# | alt_name | string |
# | amenity | string |

# %%
lines_df = OSMBusLinesProcessor.fetch(reload_pipeline=False)
lines_df.head()
# Out:
# 2025-09-21 11:26:07,549 - INFO - src.processors.osm|query_overpass:60 - Getting overpass query results in 3s
# 2025-09-21 11:26:12,155 - DEBUG - src.processors.osm|pre_process:153 - Skipping disused or abandoned bus line with id 2073673
#   gtfs_id   osm_id                                               name  \
# 0    None  2067887  Ligne A : Gare de Saint-Clair-Les-Roches ⇒ Ron...
# 1    None  2569190  Ouibus 70 : Grenoble Gare Routière -> Aéroport...
# 2    None  2569239  Ouibus 70 : Aéroport Lyon Saint-Exupéry -> Pla...
# 3    None  2920548   15 : Bois Français => Grenoble (via Chenevières)
# 4    None  2920549   15 : Grenoble => Bois Français (via Chenevières)
#
#                               from_location  \
# 0            Gare de Saint-Clair-Les-Roches
# 1                  Grenoble - Gare Routière
# 2  Aéroport Lyon Saint-Exupéry - Terminal 1
# 3              Saint Ismier - Bois Français
# 4              Grenoble - Verdun-Préfecture
#
#                                          to    network network_gtfs_id  \
# 0                         Rond-point Chanas        TPR            None
# 1  Aéroport Lyon Saint-Exupéry - Terminal 1  BlaBlaBus            None
# 2                  Grenoble - Gare routière  BlaBlaBus            None
# 3              Grenoble - Verdun-Préfecture     M réso            None
# 4              Saint Ismier - Bois Français     M réso            None
#
#   network_osm_id network_wikidata                       operator   colour  \
# 0           None             None  Courriers Rhodaniens / Fayard   e53b1a
# 1           None         Q1653380                  Faure Vercors  #ee0064
# 2           None         Q1653380                  Faure Vercors  #ee0064
# 3           None       Q131689044                            VFD  #1f72b9
# 4           None       Q131689044                            VFD  #1f72b9
#
#   text_colour stop_gtfs_ids  \
# 0        None            []
# 1        None            []
# 2        None            []
# 3        None            []
# 4        None            []
#
#                                        stops_osm_ids  school geometry  \
# 0  [1659415935, 8874916309, 11146173165, 11146173...   False     None
# 1                [2617010911, 474827289, 6074566590]   False     None
# 2                [6074566590, 457759141, 2617010911]   False     None
# 3  [2299463674, 513946287, 513946283, 513946279, ...   False     None
# 4  [372746162, 451116247, 1829688368, 1829874475,...   False     None
#
#                                                other
# 0  {'public_transport:version': '2', 'ref': 'A', ...
# 1  {'network:wikipedia': 'fr:BlaBlaCar Bus', 'old...
# 2  {'old_name': 'Satobus', 'opening_hours': 'Mo-S...
# 3  {'description': 'Circule l'été', 'opening_hour...
# 4  {'description': 'Circule l'été', 'opening_hour...

# %%
lines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1866 entries, 0 to 1865
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gtfs_id           335 non-null    object
#  1   osm_id            1866 non-null   int64
#  2   name              1866 non-null   object
#  3   from_location     1862 non-null   object
#  4   to                1862 non-null   object
#  5   network           1860 non-null   object
#  6   network_gtfs_id   0 non-null      object
#  7   network_osm_id    0 non-null      object
#  8   network_wikidata  1389 non-null   object
#  9   operator          1594 non-null   object
#  10  colour            1440 non-null   object
#  11  text_colour       34 non-null     object
#  12  stop_gtfs_ids     1866 non-null   object
#  13  stops_osm_ids     1866 non-null   object
#  14  school            1866 non-null   bool
#  15  geometry          0 non-null      object
#  16  other             1866 non-null   object
# dtypes: bool(1), int64(1), object(15)
# memory usage: 235.2+ KB

# %%
expanded = lines_df["other"].apply(pd.Series)
expanded_lines_df = pd.concat([lines_df.drop(columns=["other"]), expanded], axis=1)
expanded_lines_df.head()
# Out:
#   gtfs_id   osm_id                                               name  \
# 0    None  2067887  Ligne A : Gare de Saint-Clair-Les-Roches ⇒ Ron...
# 1    None  2569190  Ouibus 70 : Grenoble Gare Routière -> Aéroport...
# 2    None  2569239  Ouibus 70 : Aéroport Lyon Saint-Exupéry -> Pla...
# 3    None  2920548   15 : Bois Français => Grenoble (via Chenevières)
# 4    None  2920549   15 : Grenoble => Bois Français (via Chenevières)
#
#                               from_location  \
# 0            Gare de Saint-Clair-Les-Roches
# 1                  Grenoble - Gare Routière
# 2  Aéroport Lyon Saint-Exupéry - Terminal 1
# 3              Saint Ismier - Bois Français
# 4              Grenoble - Verdun-Préfecture
#
#                                          to    network network_gtfs_id  \
# 0                         Rond-point Chanas        TPR            None
# 1  Aéroport Lyon Saint-Exupéry - Terminal 1  BlaBlaBus            None
# 2                  Grenoble - Gare routière  BlaBlaBus            None
# 3              Grenoble - Verdun-Préfecture     M réso            None
# 4              Saint Ismier - Bois Français     M réso            None
#
#   network_osm_id network_wikidata                       operator  ...  \
# 0           None             None  Courriers Rhodaniens / Fayard  ...
# 1           None         Q1653380                  Faure Vercors  ...
# 2           None         Q1653380                  Faure Vercors  ...
# 3           None       Q131689044                            VFD  ...
# 4           None       Q131689044                            VFD  ...
#
#   reservation charge  url comment  fixme name:pt check_date name:eu duration  \
# 0         NaN    NaN  NaN     NaN    NaN     NaN        NaN     NaN      NaN
# 1         NaN    NaN  NaN     NaN    NaN     NaN        NaN     NaN      NaN
# 2         NaN    NaN  NaN     NaN    NaN     NaN        NaN     NaN      NaN
# 3         NaN    NaN  NaN     NaN    NaN     NaN        NaN     NaN      NaN
# 4         NaN    NaN  NaN     NaN    NaN     NaN        NaN     NaN      NaN
#
#   public_transport
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 73 columns]

# %%
expanded_lines_df.loc[4, expanded_lines_df.columns[:25]]
# Out:
# gtfs_id                                                                  None
# osm_id                                                                2920549
# name                         15 : Grenoble => Bois Français (via Chenevières)
# from_location                                    Grenoble - Verdun-Préfecture
# to                                               Saint Ismier - Bois Français
# network                                                                M réso
# network_gtfs_id                                                          None
# network_osm_id                                                           None
# network_wikidata                                                   Q131689044
# operator                                                                  VFD
# colour                                                                #1f72b9
# text_colour                                                              None
# stop_gtfs_ids                                                              []
# stops_osm_ids               [372746162, 451116247, 1829688368, 1829874475,...
# school                                                                  False
# geometry                                                                 None
# public_transport:version                                                    2
# ref                                                                        15
# route                                                                     bus
# type                                                                    route
# via                                                      Domène - Chenevières
# network:wikipedia                                                         NaN
# old_name                                                                  NaN
# opening_hours                                                         Jul-Aug
# description                                                     Circule l'été
# Name: 4, dtype: object

# %%
expanded_lines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1866 entries, 0 to 1865
# Data columns (total 73 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gtfs_id                   335 non-null    object
#  1   osm_id                    1866 non-null   int64
#  2   name                      1866 non-null   object
#  3   from_location             1862 non-null   object
#  4   to                        1862 non-null   object
#  5   network                   1860 non-null   object
#  6   network_gtfs_id           0 non-null      object
#  7   network_osm_id            0 non-null      object
#  8   network_wikidata          1389 non-null   object
#  9   operator                  1594 non-null   object
#  10  colour                    1440 non-null   object
#  11  text_colour               34 non-null     object
#  12  stop_gtfs_ids             1866 non-null   object
#  13  stops_osm_ids             1866 non-null   object
#  14  school                    1866 non-null   bool
#  15  geometry                  0 non-null      object
#  16  public_transport:version  1864 non-null   object
#  17  ref                       1862 non-null   object
#  18  route                     1866 non-null   object
#  19  type                      1866 non-null   object
#  20  via                       150 non-null    object
#  21  network:wikipedia         639 non-null    object
#  22  old_name                  11 non-null     object
#  23  opening_hours             237 non-null    object
#  24  description               73 non-null     object
#  25  wheelchair                209 non-null    object
#  26  old_ref                   93 non-null     object
#  27  not:network:wikidata      10 non-null     object
#  28  source                    18 non-null     object
#  29  roundtrip                 26 non-null     object
#  30  fee                       27 non-null     object
#  31  seasonal                  2 non-null      object
#  32  gtfs:feed                 2 non-null      object
#  33  gtfs:route_id             40 non-null     object
#  34  gtfs:shape_id             40 non-null     object
#  35  gtfs:trip_id:sample       2 non-null      object
#  36  network:guid              2 non-null      object
#  37  network:short             2 non-null      object
#  38  ref_trips                 2 non-null      object
#  39  website                   85 non-null     object
#  40  phone                     60 non-null     object
#  41  oneway                    2 non-null      object
#  42  interval                  15 non-null     object
#  43  interval:conditional      8 non-null      object
#  44  network:website           29 non-null     object
#  45  operator:wikidata         17 non-null     object
#  46  name:de                   92 non-null     object
#  47  name:fr                   89 non-null     object
#  48  name:it                   26 non-null     object
#  49  operator:wikipedia        8 non-null      object
#  50  name:hr                   2 non-null      object
#  51  note                      19 non-null     object
#  52  name:ca                   17 non-null     object
#  53  name:en                   5 non-null      object
#  54  name:es                   20 non-null     object
#  55  description:ca            4 non-null      object
#  56  description:es            4 non-null      object
#  57  description:fr            4 non-null      object
#  58  description:de            1 non-null      object
#  59  on_demand                 2 non-null      object
#  60  segment                   2 non-null      object
#  61  owner                     2 non-null      object
#  62  ownership                 2 non-null      object
#  63  reservation               1 non-null      object
#  64  charge                    15 non-null     object
#  65  url                       20 non-null     object
#  66  comment                   1 non-null      object
#  67  fixme                     13 non-null     object
#  68  name:pt                   1 non-null      object
#  69  check_date                2 non-null      object
#  70  name:eu                   3 non-null      object
#  71  duration                  3 non-null      object
#  72  public_transport          1 non-null      object
# dtypes: bool(1), int64(1), object(71)
# memory usage: 1.0+ MB

# %%
print(
    get_markdown_dtype(expanded_lines_df[expanded_lines_df.columns[:25]]).replace(
        "object", "string"
    )
)
# Out:
# | Column | Dtype |
# |--------|-------|
# | gtfs_id | string |
# | osm_id | int64 |
# | name | string |
# | from_location | string |
# | to | string |
# | network | string |
# | network_gtfs_id | string |
# | network_osm_id | string |
# | network_wikidata | string |
# | operator | string |
# | colour | string |
# | text_colour | string |
# | stop_gtfs_ids | string |
# | stops_osm_ids | string |
# | school | bool |
# | geometry | string |
# | public_transport:version | string |
# | ref | string |
# | route | string |
# | type | string |
# | via | string |
# | network:wikipedia | string |
# | old_name | string |
# | opening_hours | string |
# | description | string |
